# %% [markdown]
# # Imports

# %%
# from kfp import dsl
# from kfp.v2 import compiler
from google.cloud import aiplatform
from google.cloud import dlp_v2

from typing import List, Dict
import boto3
from botocore.exceptions import ClientError
import json, os, ast, re
import logging
import time
from datetime import datetime, timedelta
import pandas as pd, numpy as np
from scipy.special import softmax
from pydantic import BaseModel, Field, ValidationError
import pytz

import snowflake.connector as sc
from snowflake.connector.pandas_tools import write_pandas

import vertexai
import vertexai.preview.generative_models as generative_models
from vertexai.generative_models import GenerativeModel, GenerationConfig, Part

# Sentiments
from transformers import pipeline
from transformers import AutoTokenizer, AutoConfig
from transformers import AutoModelForSequenceClassification

# %% [markdown]
# # Variables

# %%
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Temporary secrets manager
with open("../secrets/configs.json", 'r') as secrets_file:
    configs = json.load(secrets_file)

loc_logs = configs.get("loc_logs")
excel_path = configs.get("excel_path")

aws_access_key = configs.get("aws_access_key")
aws_secret_key = configs.get("aws_secret_key")

# AWS
s3_source_bucket = configs.get('s3_source_bucket')
s3_transcripts_location = configs.get('s3_transcripts_location')

# GCP
gcp_project_id=configs.get('gcp_project_id')
gcp_prjct_location=configs.get('gcp_prjct_location')

# Snowflake
private_key_file = configs.get('snowflakegcp_rsa_key')
private_key_file_pwd = configs.get('snf_ssh_key_pass')


catsubcat_conn_params = {
    'account': configs.get('snf_account'),
    'user': configs.get('snf_user'),
    'private_key_file': configs.get('snf_private_key_file'),
    'private_key_file_pwd':configs.get('snf_private_key_pwd'),
    'warehouse': configs.get('snf_warehouse'),
    'database': 'POSIGEN_DEV',
    'schema': configs.get('snf_catsubcat_schema')
}

# Define the Snowflake View containing category mappings
snf_catsubcat_view = configs.get('snf_catsubcat_view')

conn_params = {
    'account': configs.get('snf_account'),
    'user': configs.get('snf_user'),
    'private_key_file': configs.get('snf_private_key_file'),
    'private_key_file_pwd':configs.get('snf_private_key_pwd'),
    'warehouse': configs.get('snf_warehouse'),
    'database': 'POSIGEN',
    'schema': configs.get('snf_schema')
}

# # Sentiment Scores
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model_sentiment = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Util Functions

# %% [markdown]
# ## Misc Utils

# %% [markdown]
# ### Initiate Master Inter and Intra Dataframes

# %%
def initiate_master_dataframes():
    if os.path.isfile("df_intra_calls_data.csv"):
        logger.info("df_intra_calls_data.csv exists.") 
        df_intra_calls_data = pd.read_csv("df_intra_calls_data.csv")
        df_intra_calls_data.CONTACT_ID = df_intra_calls_data.CONTACT_ID.astype('string')
    else:
        logger.info("df_intra_calls_data.csv does not exists.")
        df_intra_calls_data = pd.DataFrame()

    if os.path.isfile("df_inter_calls_data.csv"):
        logger.info("df_inter_calls_data.csv exists.")
        df_inter_calls_data = pd.read_csv("df_inter_calls_data.csv")
        df_inter_calls_data.CONTACT_ID = df_inter_calls_data.CONTACT_ID.astype('string')
    else:
        logger.info("df_inter_calls_data.csv does not exists.")
        df_inter_calls_data = pd.DataFrame()

    return df_intra_calls_data, df_inter_calls_data

# %% [markdown]
# ## Function: Listing Transcripts

# %%
def list_new_transcripts_from_folderlist(aws_access_key: str, aws_secret_key: str, source_bucket: str, custom_location: str, folderlist: list):
    """
    Fetch audio file from S3 and return it as a BytesIO object
    """
    
    s3_client = boto3.client(
        's3',
        aws_access_key_id=aws_access_key,
        aws_secret_access_key=aws_secret_key
    )

    logger.info("")
    logger.info("Fetching New Transcripts to process")
    all_files = []

    # Fetch files from both folders
    for folder in folderlist:
        try:
            response = s3_client.list_objects_v2(
                Bucket=s3_source_bucket,
                Prefix=folder
            )
            
            for obj in response.get('Contents', []):
                if obj['Key'].endswith('.json'):
                  # all_files.append([obj['LastModified'], obj['Key']])
                    file_path = obj['Key']
                    s3_ts = obj['LastModified']
                    # Skip if not a JSON file
                    if not file_path.endswith('.json'):
                        continue
                
                    call_id = file_path.split('/')[-1].split("_analysis_")[0] #match.group(1)
                    timestamp = datetime.strptime(file_path.split('analysis_')[-1].split('.')[0].replace('_', ':'), '%Y-%m-%dT%H:%M:%SZ') #match.group(2)    
                    all_files.append({
                        'File': file_path,
                        'ID': call_id,
                        'File_Timestamp': timestamp,
                        'File_Date': timestamp.strftime('%Y-%m-%d'),
                        'File_Time': timestamp.strftime('%H:%M:%S'),
                        'S3_Timestamp': s3_ts,
                        'S3_Date': s3_ts.strftime('%Y-%m-%d'),
                        'S3_Time': s3_ts.strftime('%H:%M:%S')
                    })
        except ClientError as e:
            logger.error(f"Error accessing S3: {e}")
            continue
        
    df_calls_list = pd.DataFrame(all_files).sort_values(['File_Timestamp'], ascending=False)
    return df_calls_list

# %% [markdown]
# ## Function: Read Transcripts

# %%
def fetch_transcript_from_s3(aws_access_key: str, aws_secret_key: str, s3_source_bucket: str, file_key):
    """
    Read Transcript JSON content from a specific file in S3.
    
    :param bucket_name: Name of the S3 bucket
    :param file_key: Full path/key of the JSON file
    :return: Parsed JSON content
    """
    s3_client = boto3.client(
            's3',
            aws_access_key_id=aws_access_key,
            aws_secret_access_key=aws_secret_key
        )
    
    try:
        # Download the file
        response = s3_client.get_object(Bucket=s3_source_bucket, Key=file_key)
        
        # Read the content
        json_content = response['Body'].read().decode('utf-8')
        
        # Parse JSON
        return json.loads(json_content)
    
    except Exception as e:
        logger.info
        logger.error(f"Error reading Transcript JSON file {file_key}: {e}")
        logger.info("")
        pass

# %% [markdown]
# ## Fetching Category, Sub-Category Mapping

# %%
def fetch_category_mapping_from_snowflake(catsubcat_conn_params):
    """Fetch Category-Subcategory mapping from a Snowflake View and return as DataFrame."""
    try:
        conn = sc.connect(**catsubcat_conn_params)
        query = f"SELECT CATEGORY, SUBCATEGORY FROM {snf_catsubcat_view}"
        df = pd.read_sql(query, conn)
        conn.close()
        return df
    except Exception as e:
        raise RuntimeError(f"Error fetching category mapping from Snowflake: {e}")

# %% [markdown]
# # Create Intra-call Dataframe

# %%
def millis_to_hhmmss(millis):
    """Convert milliseconds to mm:ss format"""
    total_seconds = int(millis / 1000)
    hours = total_seconds // 3600
    minutes = total_seconds // 60
    seconds = total_seconds % 60
    return f"{minutes:02d}:{seconds:02d}"

def convert_to_seconds(time_str):
    try:
        # Parse time string using datetime
        time_obj = datetime.strptime(time_str, '%H:%M:%S')
        # Convert to timedelta and extract total seconds
        total_seconds = time_obj.minute * 60 + time_obj.second
        return total_seconds
    except ValueError:
        pass

def process_transcript(
    transcript_data: dict,
    contact_id: str
):
    """
    Pre-process the transcript loaded from S3 Buckets:
    1. Load the transcript as Pandas Dataframe.
    2. Select only the necessary columns ['BeginOffsetMillis', 'EndOffsetMillis', 'ParticipantId', 'Content', 'Sentiment', 'LoudnessScore'].
    3. Format the time in minutes and seconds.
    4. Rename the columns for better understanding.
    """
    # Load the Transcript as Pandas Dataframe
    transcript_df = pd.json_normalize(transcript_data['Transcript'])

    # Select the relevant Columns
    columns_to_select = [
        'BeginOffsetMillis',
        'EndOffsetMillis',
        'ParticipantId',
        'Content'
    ]
    formatted_df = transcript_df[columns_to_select].copy()
    
    # Optionally rename columns to reflect their new format
    formatted_df = formatted_df.rename(columns={
        'BeginOffsetMillis': 'Begin_Offset',
        'EndOffsetMillis': 'End_Offset',
        'Content': 'caption',
        'Sentiment': 'sentiment_label',
        'ParticipantId': 'speaker_tag'
    })

    # Inserting the Call ID:
    formatted_df.insert(loc=0, column='contact_id', value=contact_id)
    formatted_df['call_language'] = transcript_data['LanguageCode']

    return formatted_df

def get_sentiment_label(row):
    # Check conditions in order of priority (Positive > Negative > Neutral)
    if row['positive'] > row['negative'] and row['positive'] > row['neutral']:
        return 'Positive'
    elif row['negative'] > row['positive'] and row['negative'] > row['neutral']:
        return 'Negative'
    else:
        return 'Neutral'

def get_sentiment_scores(text_list):
    dict_sentiments = []
    for text in text_list:
        encoded_input = tokenizer(text, return_tensors='pt')
        output = model_sentiment(**encoded_input)
        scores = output[0][0].detach().numpy()
        scores = np.round(np.multiply(softmax(scores), 100), 2)
        merged_dict = dict(zip(list(config.id2label.values()), list(scores)))
        dict_sentiments.append(merged_dict)

    df_dict_sentiments = pd.DataFrame(dict_sentiments)
    df_dict_sentiments['sentiment_lable'] = df_dict_sentiments[['positive','negative','neutral']].apply(get_sentiment_label, axis=1)
    
    return df_dict_sentiments

def get_different_times(intra_call):
    # Apply formatting to both time columns
    intra_call['start_time_second'] = (intra_call['Begin_Offset'] / 1000).astype(int)
    # intra_call['Begin_Offset'] = intra_call['Begin_Offset'].apply(millis_to_hhmmss)
    intra_call['end_time_second'] = (intra_call['End_Offset'] / 1000).astype(int)
    # intra_call['End_Offset'] = intra_call['End_Offset'].apply(millis_to_hhmmss)
    intra_call['time_spoken_second'] = intra_call['end_time_second'] - intra_call['start_time_second']
    intra_call['time_spoken_second'] = intra_call['time_spoken_second'].where(intra_call['time_spoken_second'] >= 0, 0)
    intra_call['time_spoken_second'] = intra_call['time_spoken_second'].fillna(0).astype(int)
    intra_call['time_silence_second'] = intra_call['start_time_second'].shift(-1) - intra_call['end_time_second']
    intra_call['time_silence_second'] = intra_call['time_silence_second'].where(intra_call['time_silence_second'] >= 0, 0)
    intra_call['time_silence_second'] = intra_call['time_silence_second'].fillna(0).astype(int)
    intra_call['load_date'] = datetime.now()

    # Dropping time formatted columns
    intra_call = intra_call.drop(['Begin_Offset', 'End_Offset'], axis=1)

    return intra_call

def mask_pii_in_captions(contact_id, df, project_id):
    """
    Masks PII data in the 'caption' column of a pandas DataFrame using Google Cloud DLP API.
    
    Args:
        contact_id: Identifier for logging purposes
        df (pandas.DataFrame): DataFrame with a 'caption' column to process
        project_id (str): Your Google Cloud project ID
        
    Returns:
        pandas.DataFrame: DataFrame with masked PII in the 'caption' column
    """
    logger.info(f"{contact_id}: Masking PII Data")

    # Create a copy of the DataFrame to avoid modifying the original
    masked_df = df.copy()
    
    # Add unique markers to each caption to identify them after processing
    masked_df['original_index'] = masked_df.index
    masked_df['marked_caption'] = masked_df.index.astype(str) + "|||SEPARATOR|||" + masked_df['caption'].astype(str)
    
    # Concatenate all captions for bulk processing
    all_captions = "\n===RECORD_BOUNDARY===\n".join(masked_df['marked_caption'])
    
    # Initialize DLP client
    dlp_client = dlp_v2.DlpServiceClient()
    
    # Specify the parent resource name
    parent = f"projects/{project_id}/locations/global"
    
    # Custom dictionary detector for PosiGen
    posigen_dictionary = {
        "info_type": {"name": "CUSTOM_DICTIONARY_POSIGEN"},
        "dictionary": {
            "word_list": {
                "words": ["posigen", "Posigen", "PosiGen", "POSIGEN"]
            }
        }
    }
    
    # Configure inspection config with rule set for exclusions
    inspect_config = {
        "info_types": [
            {"name": "CREDIT_CARD_NUMBER"},
            {"name": "CREDIT_CARD_EXPIRATION_DATE"},
            {"name": "STREET_ADDRESS"},
            {"name": "IP_ADDRESS"},
            {"name": "DATE_OF_BIRTH"}
        ],
        "min_likelihood": dlp_v2.Likelihood.POSSIBLE,
        "custom_info_types": [posigen_dictionary],  # ✅ Custom info types should be a list
        "rule_set": [
            {
                "info_types": [{"name": "CUSTOM_DICTIONARY_POSIGEN"}],  # ✅ Specify info_type for rule
                "rules": [
                    {
                        "exclusion_rule": {
                            "matching_type": dlp_v2.MatchingType.MATCHING_TYPE_FULL_MATCH,
                            "dictionary": {
                                "word_list": {
                                    "words": ["posigen", "Posigen", "PosiGen", "POSIGEN"]
                                }
                            }
                        }
                    }
                ]
            }
        ]
    }
    
    # Configure deidentification to use "[REDACTED]" instead of asterisks
    deidentify_config = {
        "info_type_transformations": {
            "transformations": [
                {
                    "info_types": [
                        {"name": "CREDIT_CARD_NUMBER"},
                        {"name": "CREDIT_CARD_EXPIRATION_DATE"},
                        {"name": "STREET_ADDRESS"},
                        {"name": "IP_ADDRESS"},
                        {"name": "DATE_OF_BIRTH"}
                    ],
                    "primitive_transformation": {
                        "replace_config": {
                            "new_value": {"string_value": "[REDACTED]"}
                        }
                    }
                }
            ]
        }
    }
    
    # Create deidentify request
    item = {"value": all_captions}
    
    # Call the DLP API
    try:
        response = dlp_client.deidentify_content(
            request={
                "parent": parent,
                "deidentify_config": deidentify_config,
                "inspect_config": inspect_config,
                "item": item,
            }
        )
    except Exception as e:
        logger.error(f"{contact_id}: Error in DLP API call: {e}")
        return df  # Return original DataFrame if masking fails

    # Get processed content and split by record boundaries
    processed_content = response.item.value
    processed_records = processed_content.split("\n===RECORD_BOUNDARY===\n")
    
    # Create mapping from original indices to processed captions
    processed_dict = {}
    for record in processed_records:
        parts = record.split("|||SEPARATOR|||", 1)
        if len(parts) == 2:
            idx, content = parts
            processed_dict[int(idx)] = content
    
    # Update the DataFrame with redacted content
    masked_df['caption'] = masked_df.apply(
        lambda row: processed_dict.get(row['original_index'], row['caption']), 
        axis=1
    )
    
    # Additional processing to mask all digits with asterisks
    def mask_digits(text):
        """Replaces digits with asterisks while preserving '[REDACTED]' markers."""
        if not isinstance(text, str):
            return text
        parts = text.split("[REDACTED]")
        for i in range(len(parts)):
            parts[i] = re.sub(r'\d', '*', parts[i])
        return "[REDACTED]".join(parts)
    
    # Apply the digit masking function to each processed caption
    masked_df['caption'] = masked_df['caption'].apply(mask_digits)
    
    # Drop temporary columns
    masked_df.drop(['original_index', 'marked_caption'], axis=1, inplace=True)
    
    logger.info(f"{contact_id}: Completed Masking PII Data")
    return masked_df
    
    
def create_intra_call_df(aws_access_key: str, aws_secret_key: str, transcript_data: dict, contact_id: str, gcp_project_id: str):
    intra_call = process_transcript(transcript_data, contact_id)        
    df_sentiment_scores = get_sentiment_scores(intra_call.caption.to_list())
    intra_call = pd.concat([intra_call, df_sentiment_scores], axis=1)    
    intra_call = get_different_times(intra_call)
    intra_call = mask_pii_in_captions(contact_id, intra_call, gcp_project_id)
    
    return intra_call

# %% [markdown]
# # Create Inter-call Dataframe

# %%
class CategoryValidator:
    def __init__(self, cat_subcat_mapping):
        """
        Initialize with category mapping from a Snowflake View.
        :param snowflake_conn_params: Dictionary containing Snowflake connection details.
        :param view_name: Name of the Snowflake View containing category mappings.
        """
        self.category_mapping = cat_subcat_mapping
        self.valid_categories = set(self.category_mapping['CATEGORY'].unique())
        self.category_subcategory_map = self._create_category_mapping()

    def _create_category_mapping(self):
        """Create category to subcategory mapping."""
        mapping = {}
        for _, row in self.category_mapping.iterrows():
            if row['CATEGORY'] not in mapping:
                mapping[row['CATEGORY']] = set()
            mapping[row['CATEGORY']].add(row['SUBCATEGORY'])
        return mapping

    def validate_category(self, category: str) -> bool:
        """Check if category is valid."""
        return category in self.valid_categories

    def validate_subcategory(self, category: str, subcategory: str) -> bool:
        """Check if subcategory is valid for given category."""
        return category in self.category_subcategory_map and subcategory in self.category_subcategory_map[category]

    def get_valid_subcategories(self, category: str):
        """Get valid subcategories for a category."""
        return self.category_subcategory_map.get(category, set())

class CallSummary(BaseModel):
    summary: str = Field(..., max_length=500)
    # key_points: List[str] = Field(..., max_items=5)
    # outcome: str = Field(..., max_length=200)
    # follow_up_recommendations: List[str] = Field(..., max_items=3)

class CallTopic(BaseModel):
    primary_topic: str = Field(..., max_length=100)
    category: str = Field(..., max_length=100)
    sub_category: str = Field(..., max_length=100)

    def validate_category_mapping(self, category_validator: CategoryValidator) -> bool:
        """Validate category and subcategory against mapping"""
        if not category_validator.validate_category(self.category):
            logger.error(f"Invalid category: {self.category}")
        if not category_validator.validate_subcategory(self.category, self.sub_category):
            logger.error(f"Invalid subcategory '{self.sub_category}' for category '{self.category}'")

class AgentCoaching(BaseModel):
    strengths: List[str] = Field(..., max_items=3)
    improvement_areas: List[str] = Field(..., max_items=3)
    specific_recommendations: List[str] = Field(..., max_items=4)
    skill_development_focus: List[str] = Field(..., max_items=3)

class TranscriptAnalysis(BaseModel):
    call_summary: CallSummary
    call_topic: CallTopic
    agent_coaching: AgentCoaching

class KPIExtractor:
    def __init__(self, project_id: str, location: str, excel_path: str):
        vertexai.init(project=project_id, location=location)
        self.model = GenerativeModel("gemini-1.5-flash-002")
        self.category_validator = CategoryValidator(cat_subcat_mapping)
        
        self.generation_config = {
            "temperature": 0.3,
            "max_output_tokens": 1024,
            "top_p": 0.8,
            "top_k": 40,
            "response_format": "json"
        }
        
        self.safety_settings = {
            generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
            generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
            generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
            generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
        }

    
    def get_categories_prompt(self) -> str:
        """Create prompt section for valid categories and subcategories, handling null values"""
        categories_prompt = []
        
        for category, subcategories in self.category_validator.category_subcategory_map.items():
            if category is None:  # Skip if category is None
                continue
            
            # Ensure subcategories are valid (remove None values)
            valid_subcategories = [subcat for subcat in subcategories if subcat is not None]
            
            if valid_subcategories:
                subcats = ', '.join(sorted(valid_subcategories))
            else:
                subcats = "No defined subcategories"
            
            categories_prompt.append(f"Category '{category}' can have subcategories: {subcats}")
        
        return '\n'.join(categories_prompt)

    def create_prompt(self, transcript: str) -> str:
        """Create structured prompt with category guidance"""
        categories_guidance = self.get_categories_prompt()
        
        return f"""
        Analyze this call transcript and provide a structured analysis in the exact JSON format specified below.
        Keep responses concise, specific, and actionable.
    
        Guidelines:
        - Call summary should be factual and highlight key interactions
        - Topics and categories MUST match the following valid mappings:
        {categories_guidance}
        - Coaching points should be specific and actionable
        - All responses must follow the exact structure specified
        - Ensure all lists have the specified maximum number of items
        - All text fields must be clear, professional, and free of fluff
    
        Transcript:
        {transcript}
    
        Required Output Structure:
        {{
            "call_summary": {{
                "summary": "3-4 line overview of the call"
            }},
            "call_topic": {{
                "primary_topic": "Main topic of discussion",
                "category": "MUST BE ONE OF THE VALID CATEGORIES LISTED ABOVE",
                "sub_category": "MUST BE A VALID SUB-CATEGORY FOR THE CHOSEN CATEGORY"
            }},
            "agent_coaching": {{
                "strengths": ["Strength 1", "Strength 2", "Strength 3"],
                "improvement_areas": ["Area 1", "Area 2", "Area 3"],
                "specific_recommendations": ["Rec 1", "Rec 2", "Rec 3", "Rec 4"],
                "skill_development_focus": ["Skill 1", "Skill 2", "Skill 3"]
            }}
        }}
    
        Rules:
        1. Maintain exact JSON structure
        2. No additional fields or comments
        3. No markdown formatting
        4. Ensure all arrays have the exact number of items specified
        5. Keep all text concise and professional
        6. Do not mention any PII information such as Customer Name etc.
        7. STRICTLY use only the categories and subcategories from the provided mapping
        """
    
    def extract_json(self, response: str) -> Dict:
        """Extract valid JSON from response"""
        match = re.search(r'```json\s*([\s\S]*?)\s*```', response)
        if match:
            json_str = match.group(1)
        else:
            json_str = response.strip()
        
        try:
           return json.loads(json_str)
        except json.JSONDecodeError:
           logger.error("Invalid JSON response")
           pass

    def validate_response(self, response_json: Dict, contact_id: str = None) -> TranscriptAnalysis:
        """Validate response using Pydantic models and category mapping"""
        try:
            # First validate basic structure with Pydantic
            analysis = TranscriptAnalysis(**response_json)
            
            # Then validate category mapping
            analysis.call_topic.validate_category_mapping(self.category_validator)
            
            return analysis
        except ValidationError as e:
            logger.error(f"{contact_id if contact_id else ''}: Pydantic validation error - {e}")
            pass
        except ValueError as e:
            logger.error(f"{contact_id if contact_id else ''}: Category validation error - {e}")
            pass


    def extract_genai_kpis(
       self,
       transcript: str,
       contact_id: str = None
    ):
        """Extract KPIs from transcript with validation and retries"""
        max_retries = 3
        attempt = 0
    
        while attempt < max_retries:
            try:
                # Generate prompt
                prompt = self.create_prompt(transcript)
    
                # Get response from Gemini
                response = self.model.generate_content(prompt)
    
                # Parse JSON response
                response_json = self.extract_json(response.text)
    
                # If response is empty, retry
                if not response_json or "NA" in response_json.values():
                    logger.warning(f"Attempt {attempt + 1}: Gemini returned NA or empty response. Retrying...")
                    attempt += 1
                    time.sleep(2)  # Wait before retrying
                    continue
    
                # Validate response
                validated_response = self.validate_response(response_json, contact_id)
    
                if validated_response:
                    return validated_response.model_dump()
    
                logger.warning(f"Attempt {attempt + 1}: Invalid response structure. Retrying...")
                attempt += 1
                time.sleep(2)  # Wait before retrying
    
            except Exception as e:
                logger.error(f"Attempt {attempt + 1}: Error extracting KPIs: {str(e)}")
                attempt += 1
                time.sleep(2)  # Wait before retrying
    
        logger.error(f"Failed to extract valid KPIs after {max_retries} attempts.")
        return {"error": "Failed to extract KPIs after multiple attempts"}

def dict_to_newline_string(data: dict) -> str:
    """Converts a dictionary into a new-line formatted string."""
    formatted_str = ""
    for key, value in data.items():
        formatted_str += f"{key}:\n"
        for item in value:
            formatted_str += f"  - {item}\n"
    return formatted_str.strip()

def create_inter_call_df(
    gcp_project_id: str,
    gcp_prjct_location: str,
    df_intra_call: pd.DataFrame,
    transcript_data: dict,
    ac_last_modified_date: datetime,
    cat_subcat_mapping: pd.DataFrame
):
    try:
        contact_id = df_intra_call.contact_id.unique        
    
        # logger.info(f"{contact_id}: Extracting KPIs from Gemini")      
        extractor = KPIExtractor(gcp_project_id, gcp_prjct_location, excel_path)
        transcript = " ".join(df_intra_call.caption)
        call_gen_kpis = extractor.extract_genai_kpis(transcript)
        # logger.info(f"{contact_id}: Completed Extracting KPIs from Gemini") 
    
        # logger.info(f"{contact_id}: Creating Inter Call df")
        inter_call_dict = {}
        inter_call_dict['contact_id'] = str(df_intra_call['contact_id'][0])
        inter_call_dict['call_text'] = " ".join(df_intra_call.caption)
        inter_call_dict['call_summary'] = call_gen_kpis['call_summary']['summary']
        inter_call_dict['topic'] = call_gen_kpis['call_topic']['primary_topic']
        inter_call_dict['category'] = call_gen_kpis['call_topic']['category']
        # inter_call_dict['category_generated'] = call_gen_kpis['call_topic']['category']
        inter_call_dict['sub_category'] = call_gen_kpis['call_topic']['sub_category']
        # inter_call_dict['sub_category_generated'] = call_gen_kpis['call_topic']['sub_category']
        inter_call_dict['agent_coaching'] = dict_to_newline_string(call_gen_kpis['agent_coaching'])
    
        df_inter_call = pd.DataFrame(pd.Series(inter_call_dict)).T
    
        # Add metadata from AWS
        # df_inter_call['account_id'] = transcript_data['AccountId']
        df_inter_call['agent_speech_speed'] = transcript_data['ConversationCharacteristics']['TalkSpeed']['DetailsByParticipant']['AGENT']['AverageWordsPerMinute']
        df_inter_call['customer_speech_speed'] = transcript_data['ConversationCharacteristics']['TalkSpeed']['DetailsByParticipant']['CUSTOMER']['AverageWordsPerMinute']
        df_inter_call['total_talktime_agent_second'] = int(transcript_data['ConversationCharacteristics']['TalkTime']['DetailsByParticipant']['AGENT']['TotalTimeMillis']/1000)
        df_inter_call['total_talktime_customer_second'] = int(transcript_data['ConversationCharacteristics']['TalkTime']['DetailsByParticipant']['CUSTOMER']['TotalTimeMillis']/1000)
        df_inter_call['total_talktime_call_second'] = int(transcript_data['ConversationCharacteristics']['TalkTime']['TotalTimeMillis']/1000)
        df_inter_call['total_duration_call_second'] = int(transcript_data['ConversationCharacteristics']['TotalConversationDurationMillis']/1000)
        df_inter_call['total_dead_air_call_second'] = df_inter_call['total_duration_call_second'] - df_inter_call['total_talktime_call_second']
        # df_inter_call['customer_instance_id'] = transcript_data['CustomerMetadata']['InstanceId']
        # df_inter_call['call_job_status'] = transcript_data['JobStatus']
        df_inter_call['call_language'] = transcript_data['LanguageCode']
        df_inter_call['call_s3_uri'] = transcript_data['CustomerMetadata']['InputS3Uri']
        df_inter_call['ac_last_modified_date'] = ac_last_modified_date
        # df_inter_call['load_date'] = datetime.now()
        
        return df_inter_call

    except Exception as e:
        logger.info
        logger.error(f"{contact_id}: Error Creating Intra Call df: {e}")
        logger.info("")
        pass

# %% [markdown]
# # Writing Dataframe to Snowflake

# %%
def insert_new_records(conn, table_name, df):
    """
    Inserts only new records (based on ID) into Snowflake table with UTC load timestamp.

    Steps:
    1. Fetches existing IDs from table.
    2. Filters out rows with existing IDs from DataFrame.
    3. Adds 'LOAD_DATE_UTC' column with current UTC timestamp.
    4. Inserts only new records.

    Args:
        conn: Snowflake connection object.
        table_name (str): Name of the target table.
        df (pd.DataFrame): DataFrame containing the data (must have 'CONTACT_ID' column).

    Returns:
        int: Number of inserted records.
    """    
    cursor = conn.cursor()

    # Step 1: Get existing IDs from Snowflake table
    cursor.execute(f"SELECT DISTINCT(CONTACT_ID) FROM {table_name}")
    existing_ids = {row[0] for row in cursor.fetchall()}
    
    # Step 2: Filter DataFrame to keep only new records
    new_records_df = df[~df['CONTACT_ID'].isin(existing_ids)]
    
    if new_records_df.empty:
        logger.info("No new records to insert")
        return 0
    
    # Step 3: Add UTC timestamp column
    utc_now = datetime.now(pytz.utc).strftime('%Y-%m-%d %H:%M:%S')
    new_records_df = new_records_df.copy()  # Avoid modifying original df
    new_records_df["LOAD_DATE"] = utc_now  # Add new column

    # Step 4: Insert new records into Snowflake
    success, nchunks, nrows, _ = write_pandas(conn, new_records_df, table_name)
    
    logger.info(f"Inserted {nrows} new records with UTC load date")
    logger.info(f"Skipped {len(df) - len(new_records_df)} existing records")
    
    cursor.close()
    return nrows

# %% [markdown]
# ### Handel Duplicates

# %%
def handle_duplicates(data_frame, columns_to_check):
    """
    Dedupes the final Dataframes to be written to the Snowflake Tables
    """
    # Remove duplicate records based on the specified columns, keeping the first occurrence
    df_cleaned = data_frame.drop_duplicates(subset=columns_to_check, keep="first")

    # (Optional) Reset index after removing duplicates
    df_cleaned = df_cleaned.reset_index(drop=True)

    return df_cleaned

# %% [markdown]
# # Exception Handling

# %% [markdown]
# # Logging Handling

# %%
def setup_logger(log_file):
    """
    Sets up a logger that writes to both file and console with timestamp.

    Args:
        log_file (str): Name of the log file to write to.

    Returns:
        logger: Configured logger instance.
    """
    logger = logging.getLogger('voice_ai_logger')

    # Reset handlers if already exist
    if logger.hasHandlers():
        logger.handlers.clear()

    # Set log level
    logger.setLevel(logging.DEBUG)

    # Create formatter
    formatter = logging.Formatter(
        '%(asctime)s [%(levelname)s]: %(message)s', datefmt='%Y-%m-%d %H:%M:%S'
    )

    # Create file handler
    file_handler = logging.FileHandler(log_file)
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    # Create a stream handler (console)
    console_handler = logging.StreamHandler()
    console_handler.setFormatter(formatter)
    logger.addHandler(console_handler)

    return logger


def reset_logging():
    """Removes all logging handlers and resets the logger."""
    # Get all loggers
    loggers = list(logging.root.manager.loggerDict.values())
    
    # Include root logger explicitly
    loggers.append(logging.getLogger())

    for logger in loggers:
        if isinstance(logger, logging.Logger):  # Ensure it's a valid logger instance
            for handler in logger.handlers[:]:  # Copy list to avoid modification issues
                logger.removeHandler(handler)
                handler.close()

            logger.setLevel(logging.NOTSET)
            logger.propagate = False  # Avoid duplicate logs from propagation

# %% [markdown]
# # Main Function

# %%
# Get current date
current_date = datetime.now()

# Get dates for last 2 days
num_days = 6
dates_to_check = []
for i in range(num_days):
    check_date = current_date - timedelta(days=i)
    dates_to_check.append(check_date)

# Process each date
folderlist = []
for date in dates_to_check:
    year = str(date.year)
    month = f"{date.month:02d}"
    day = f"{date.day:02d}"
    
    # Construct the prefix for S3 listing
    prefix = f"{s3_transcripts_location}/{year}/{month}/{day}/"
    folderlist.append(prefix)
folderlist
# Out:
# ['Analysis/Voice/2025/03/04/',
#  'Analysis/Voice/2025/03/03/',
#  'Analysis/Voice/2025/03/02/',
#  'Analysis/Voice/2025/03/01/',
#  'Analysis/Voice/2025/02/28/',
#  'Analysis/Voice/2025/02/27/']

# %%
reset_logging()

# Setup logger
log_file='voice_ai_runtime.logs'
logger = setup_logger(log_file)

# Initiating Master DataFrames
logger.info("Called: Initiate Master Dataframes")
df_intra_calls_data, df_inter_calls_data = initiate_master_dataframes()

logger.info("Fetching Category, Sub-category Mapping.")
cat_subcat_mapping = fetch_category_mapping_from_snowflake(catsubcat_conn_params)

# Get the transcripts in to_process_folder
df_list_transcripts = list_new_transcripts_from_folderlist(aws_access_key, aws_secret_key, s3_source_bucket, s3_transcripts_location, folderlist)

logger.info("")
logger.info(f"Transcripts to process: {len(df_list_transcripts)}")
logger.info("")
# Out:
# 2025-03-04 15:47:33 [INFO]: Called: Initiate Master Dataframes
# 2025-03-04 15:47:33 [INFO]: df_intra_calls_data.csv exists.
# 2025-03-04 15:47:33 [INFO]: df_inter_calls_data.csv exists.
# 2025-03-04 15:47:33 [INFO]: Fetching Category, Sub-category Mapping.
# /var/tmp/ipykernel_16556/3783910305.py:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
# 2025-03-04 15:47:34 [INFO]:
# 2025-03-04 15:47:34 [INFO]: Fetching New Transcripts to process
# 2025-03-04 15:47:35 [INFO]:
# 2025-03-04 15:47:35 [INFO]: Transcripts to process: 3348
# 2025-03-04 15:47:35 [INFO]:

# %%
# If there are transcripts to be processed
if len(df_list_transcripts) == 0:
    logger.info("No Transcripts to Process")
    logger.info("")

else:
    for transcript in df_list_transcripts.File.to_list():
        logger.info("--------------------------")
        start_time = time.time()
        try:
            # get the call ID
            contact_id = transcript.split('/')[-1].split('.')[0].split('analysis')[0].strip('_')
            ac_last_modified_date = pd.to_datetime(transcript.split('analysis_')[-1].split('.')[0].replace('_', ':'))
    
            # Check if Call Already Processed
            if (len(df_intra_calls_data) > 0 and contact_id in df_intra_calls_data.CONTACT_ID.unique()) and (len(df_inter_calls_data) > 0 and contact_id in df_inter_calls_data.CONTACT_ID.unique()):
                logger.info(f"{contact_id}: Call already Processed.")
                # break
    
            else:
                # get the audio transcript file name
                logger.info(f"{contact_id}: Processing") 
                
                # Get the Transcript file from S3 Bucket
                logger.info(f"{contact_id}: Fetching Transcript from S3")
                transcript_data = fetch_transcript_from_s3(aws_access_key, aws_secret_key, s3_source_bucket, transcript)
                logger.info(f"{contact_id}: Successfully fetched the Transcript from S3")
            
                # Create the Inter Call KPIs
                logger.info(f"{contact_id}: Creating df_intra_call ")
                df_intra_call = create_intra_call_df(aws_access_key, aws_secret_key, transcript_data, contact_id, gcp_project_id)
                logger.info(f"{contact_id}: Successfully created df_intra_call ")
            
                # Create the Intra Call KPIs
                logger.info(f"{contact_id}: Creating df_inter_call ")
                df_inter_call = create_inter_call_df(gcp_project_id, gcp_prjct_location, df_intra_call, transcript_data, ac_last_modified_date, cat_subcat_mapping)
                logger.info(f"{contact_id}: Successfully created df_inter_call ")


                # ###============================================================###
                # Save DataFrames only when both are having data
                if not df_intra_call.empty and not df_inter_call.empty:
                    # Appending to Intra-calls Master DataFrame
                    df_intra_call.columns = df_intra_call.columns.str.upper()  # Capitalising Column names for Snowflake
                    df_intra_calls_data = pd.concat([df_intra_calls_data, df_intra_call], ignore_index=True)
                    df_intra_calls_data.to_csv("df_intra_calls_data.csv", index=False)
                    logger.info(f"{contact_id}: Persisted df_intra_calls_data to CSV.")
                    
                    # Appending to Inter-calls Master DataFrame
                    df_inter_call.columns = df_inter_call.columns.str.upper()  # Capitalising Column names for Snowflake
                    df_inter_calls_data = pd.concat([df_inter_calls_data, df_inter_call], ignore_index=True)
                    df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
                    logger.info(f"{contact_id}: Persisted df_intra_calls_data to CSV.")
                    # logger.info(f"{contact_id}: Processing Complete")
                    
                else:
                    if df_intra_call.empty:
                        logger.error("Intra Call DataFrame was not created successfully.")
                    if df_inter_call.empty:
                        logger.error("Inter Call DataFrame was not created successfully.")
            
            if len(df_inter_calls_data)%20 == 0:
                logger.info("--------------------------")
                logger.info(f"Processed {len(df_inter_calls_data)} files")
                logger.info("--------------------------")
        
        except Exception as e:
            logger.error("--------------------------")
            logger.error(f"{contact_id}: Exception - {e}")
            logger.error("--------------------------")
            continue

            
        end_time = time.time()
        elapsed_time = end_time - start_time  # Time taken for this iteration
        minutes, seconds = divmod(elapsed_time, 60)
        logger.info(f"{contact_id}: Processed Call #{len(df_inter_calls_data)} in {int(minutes)} min {seconds:.2f} sec elapsed")
        logger.info("--------------------------")
        logger.info("")
        logger.info("")
        
    # logger.info(f"Removing duplicates in df_inter_calls_data.")
    # columns_to_check = ["CONTACT_ID"]
    # df_inter_calls_data = handle_duplicates(df_inter_calls_data, columns_to_check)
    # df_inter_calls_data["AC_LAST_MODIFIED_DATE"] = pd.to_datetime(df_inter_calls_data["AC_LAST_MODIFIED_DATE"])
    # logger.info(f"Removing duplicates in df_intra_calls_data.")
    # columns_to_check = ["CONTACT_ID", "SPEAKER_TAG", "CAPTION", "START_TIME_SECOND", "END_TIME_SECOND"]
    # df_intra_calls_data = handle_duplicates(df_intra_calls_data, columns_to_check)
    
    

    # logger.info(f"Writing Dataframe to Snowflake.")
    # conn = sc.connect(**conn_params)
    # table_name ='SRC_GCP_INTER_CALLS'    
    # logger.info(f"Writing data to table: {conn_params['database']}.{table_name}")
    # insert_new_records(conn, table_name, df_inter_calls_data)

    # logger.info(f"Writing data to table: {conn_params['database']}.{table_name}")
    # table_name ='SRC_GCP_INTRA_CALLS'
    # insert_new_records(conn, table_name, df_intra_calls_data)
    # conn.close()

    # logger.info(f"Completed processing {len(df_list_transcripts)} Calls")
# Out:
# 2025-03-04 15:47:35 [INFO]: --------------------------
# 2025-03-04 15:47:35 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Processing
# 2025-03-04 15:47:35 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Fetching Transcript from S3
# 2025-03-04 15:47:35 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:35 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Creating df_intra_call
# 2025-03-04 15:47:36 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Masking PII Data
# 2025-03-04 15:47:36 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Completed Masking PII Data
# 2025-03-04 15:47:36 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Successfully created df_intra_call
# 2025-03-04 15:47:36 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Creating df_inter_call
# 2025-03-04 15:47:38 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Successfully created df_inter_call
# 2025-03-04 15:47:38 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:38 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:38 [INFO]: a0298a2f-3e2d-4f9a-9a29-bfce9802d552: Processed Call #2894 in 0 min 3.45 sec elapsed
# 2025-03-04 15:47:38 [INFO]: --------------------------
# 2025-03-04 15:47:38 [INFO]:
# 2025-03-04 15:47:38 [INFO]:
# 2025-03-04 15:47:38 [INFO]: --------------------------
# 2025-03-04 15:47:38 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Processing
# 2025-03-04 15:47:38 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Fetching Transcript from S3
# 2025-03-04 15:47:38 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:38 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Creating df_intra_call
# 2025-03-04 15:47:39 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Masking PII Data
# 2025-03-04 15:47:39 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Completed Masking PII Data
# 2025-03-04 15:47:39 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Successfully created df_intra_call
# 2025-03-04 15:47:39 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Creating df_inter_call
# 2025-03-04 15:47:40 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Successfully created df_inter_call
# 2025-03-04 15:47:41 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:41 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:41 [INFO]: 29cac76c-a5ac-42c6-bae9-2c1641625a73: Processed Call #2895 in 0 min 2.79 sec elapsed
# 2025-03-04 15:47:41 [INFO]: --------------------------
# 2025-03-04 15:47:41 [INFO]:
# 2025-03-04 15:47:41 [INFO]:
# 2025-03-04 15:47:41 [INFO]: --------------------------
# 2025-03-04 15:47:41 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Processing
# 2025-03-04 15:47:41 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Fetching Transcript from S3
# 2025-03-04 15:47:41 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:41 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Creating df_intra_call
# 2025-03-04 15:47:42 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Masking PII Data
# 2025-03-04 15:47:42 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Completed Masking PII Data
# 2025-03-04 15:47:42 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Successfully created df_intra_call
# 2025-03-04 15:47:42 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Creating df_inter_call
# 2025-03-04 15:47:44 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Successfully created df_inter_call
# 2025-03-04 15:47:44 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:44 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:44 [INFO]: d7772069-e98c-40b1-9d72-25bba2084ca3: Processed Call #2896 in 0 min 3.21 sec elapsed
# 2025-03-04 15:47:44 [INFO]: --------------------------
# 2025-03-04 15:47:44 [INFO]:
# 2025-03-04 15:47:44 [INFO]:
# 2025-03-04 15:47:44 [INFO]: --------------------------
# 2025-03-04 15:47:44 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Processing
# 2025-03-04 15:47:44 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Fetching Transcript from S3
# 2025-03-04 15:47:44 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:44 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Creating df_intra_call
# 2025-03-04 15:47:49 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Masking PII Data
# 2025-03-04 15:47:49 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Completed Masking PII Data
# 2025-03-04 15:47:49 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Successfully created df_intra_call
# 2025-03-04 15:47:49 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Creating df_inter_call
# 2025-03-04 15:47:51 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Successfully created df_inter_call
# 2025-03-04 15:47:51 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:51 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:51 [INFO]: 9c6733eb-af27-4b34-87f1-f2e83b80f105: Processed Call #2897 in 0 min 7.14 sec elapsed
# 2025-03-04 15:47:51 [INFO]: --------------------------
# 2025-03-04 15:47:51 [INFO]:
# 2025-03-04 15:47:51 [INFO]:
# 2025-03-04 15:47:51 [INFO]: --------------------------
# 2025-03-04 15:47:51 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Processing
# 2025-03-04 15:47:51 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Fetching Transcript from S3
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Creating df_intra_call
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Masking PII Data
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Completed Masking PII Data
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Successfully created df_intra_call
# 2025-03-04 15:47:52 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Creating df_inter_call
# 2025-03-04 15:47:54 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Successfully created df_inter_call
# 2025-03-04 15:47:55 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:55 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:55 [INFO]: ba785251-f811-4858-9ae9-af1ece5d874e: Processed Call #2898 in 0 min 3.34 sec elapsed
# 2025-03-04 15:47:55 [INFO]: --------------------------
# 2025-03-04 15:47:55 [INFO]:
# 2025-03-04 15:47:55 [INFO]:
# 2025-03-04 15:47:55 [INFO]: --------------------------
# 2025-03-04 15:47:55 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Processing
# 2025-03-04 15:47:55 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Fetching Transcript from S3
# 2025-03-04 15:47:55 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:55 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Creating df_intra_call
# 2025-03-04 15:47:55 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Masking PII Data
# 2025-03-04 15:47:56 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Completed Masking PII Data
# 2025-03-04 15:47:56 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Successfully created df_intra_call
# 2025-03-04 15:47:56 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Creating df_inter_call
# 2025-03-04 15:47:58 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Successfully created df_inter_call
# 2025-03-04 15:47:58 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:59 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:47:59 [INFO]: f4f6b35c-3740-4dee-8153-d2321633f823: Processed Call #2899 in 0 min 3.76 sec elapsed
# 2025-03-04 15:47:59 [INFO]: --------------------------
# 2025-03-04 15:47:59 [INFO]:
# 2025-03-04 15:47:59 [INFO]:
# 2025-03-04 15:47:59 [INFO]: --------------------------
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Processing
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Fetching Transcript from S3
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Successfully fetched the Transcript from S3
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Creating df_intra_call
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Masking PII Data
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Completed Masking PII Data
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Successfully created df_intra_call
# 2025-03-04 15:47:59 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Creating df_inter_call
# 2025-03-04 15:48:02 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Successfully created df_inter_call
# 2025-03-04 15:48:02 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:02 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:02 [INFO]: --------------------------
# 2025-03-04 15:48:02 [INFO]: Processed 2900 files
# 2025-03-04 15:48:02 [INFO]: --------------------------
# 2025-03-04 15:48:02 [INFO]: 2ba19c38-5d71-49c0-99bb-3dcad08d80d2: Processed Call #2900 in 0 min 3.67 sec elapsed
# 2025-03-04 15:48:02 [INFO]: --------------------------
# 2025-03-04 15:48:02 [INFO]:
# 2025-03-04 15:48:02 [INFO]:
# 2025-03-04 15:48:02 [INFO]: --------------------------
# 2025-03-04 15:48:02 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Processing
# 2025-03-04 15:48:02 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Fetching Transcript from S3
# 2025-03-04 15:48:02 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:02 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Creating df_intra_call
# 2025-03-04 15:48:03 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Masking PII Data
# 2025-03-04 15:48:03 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Completed Masking PII Data
# 2025-03-04 15:48:03 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Successfully created df_intra_call
# 2025-03-04 15:48:03 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Creating df_inter_call
# 2025-03-04 15:48:05 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Successfully created df_inter_call
# 2025-03-04 15:48:05 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:05 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:05 [INFO]: f9f6ab26-ecb3-4537-99c1-8f3d84c4e376: Processed Call #2901 in 0 min 2.86 sec elapsed
# 2025-03-04 15:48:05 [INFO]: --------------------------
# 2025-03-04 15:48:05 [INFO]:
# 2025-03-04 15:48:05 [INFO]:
# 2025-03-04 15:48:05 [INFO]: --------------------------
# 2025-03-04 15:48:05 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Processing
# 2025-03-04 15:48:05 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Fetching Transcript from S3
# 2025-03-04 15:48:05 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:05 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Creating df_intra_call
# 2025-03-04 15:48:11 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Masking PII Data
# 2025-03-04 15:48:11 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Completed Masking PII Data
# 2025-03-04 15:48:11 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Successfully created df_intra_call
# 2025-03-04 15:48:11 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Creating df_inter_call
# 2025-03-04 15:48:13 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Successfully created df_inter_call
# 2025-03-04 15:48:14 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:14 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:14 [INFO]: 4437f49a-58af-49fc-bd7c-9f22d9fc624d: Processed Call #2902 in 0 min 8.67 sec elapsed
# 2025-03-04 15:48:14 [INFO]: --------------------------
# 2025-03-04 15:48:14 [INFO]:
# 2025-03-04 15:48:14 [INFO]:
# 2025-03-04 15:48:14 [INFO]: --------------------------
# 2025-03-04 15:48:14 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Processing
# 2025-03-04 15:48:14 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Fetching Transcript from S3
# 2025-03-04 15:48:17 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:17 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Creating df_intra_call
# 2025-03-04 15:48:19 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Masking PII Data
# 2025-03-04 15:48:19 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Completed Masking PII Data
# 2025-03-04 15:48:19 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Successfully created df_intra_call
# 2025-03-04 15:48:19 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Creating df_inter_call
# 2025-03-04 15:48:21 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Successfully created df_inter_call
# 2025-03-04 15:48:21 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:22 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:22 [INFO]: 0957a2de-14de-4c70-b7fa-5b569d5ac15d: Processed Call #2903 in 0 min 7.85 sec elapsed
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]: c3618b6c-f72b-43a7-a494-8f097122e5ea: Call already Processed.
# 2025-03-04 15:48:22 [INFO]: c3618b6c-f72b-43a7-a494-8f097122e5ea: Processed Call #2903 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]: a3a36879-d1b5-415e-9400-43c25d422407: Call already Processed.
# 2025-03-04 15:48:22 [INFO]: a3a36879-d1b5-415e-9400-43c25d422407: Processed Call #2903 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]: 314b2ba0-6b92-42d7-b293-c2ef7369042b: Call already Processed.
# 2025-03-04 15:48:22 [INFO]: 314b2ba0-6b92-42d7-b293-c2ef7369042b: Processed Call #2903 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]:
# 2025-03-04 15:48:22 [INFO]: --------------------------
# 2025-03-04 15:48:22 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Processing
# 2025-03-04 15:48:22 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Fetching Transcript from S3
# 2025-03-04 15:48:23 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:23 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Creating df_intra_call
# 2025-03-04 15:48:30 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Masking PII Data
# 2025-03-04 15:48:31 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Completed Masking PII Data
# 2025-03-04 15:48:31 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Successfully created df_intra_call
# 2025-03-04 15:48:31 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Creating df_inter_call
# 2025-03-04 15:48:33 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Successfully created df_inter_call
# 2025-03-04 15:48:34 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:34 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:34 [INFO]: 0f9caddf-d262-4d85-a5cc-658fa3861f8b: Processed Call #2904 in 0 min 12.04 sec elapsed
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]: 9e52341e-137d-4fac-9eb4-3d0686d51d63: Call already Processed.
# 2025-03-04 15:48:34 [INFO]: 9e52341e-137d-4fac-9eb4-3d0686d51d63: Processed Call #2904 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]: 9b93e502-5fdb-40fb-b893-cd9647ce9bca: Call already Processed.
# 2025-03-04 15:48:34 [INFO]: 9b93e502-5fdb-40fb-b893-cd9647ce9bca: Processed Call #2904 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]: 8c1cfc4a-ec91-4cc4-82ae-b7f090df6fa7: Call already Processed.
# 2025-03-04 15:48:34 [INFO]: 8c1cfc4a-ec91-4cc4-82ae-b7f090df6fa7: Processed Call #2904 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]:
# 2025-03-04 15:48:34 [INFO]: --------------------------
# 2025-03-04 15:48:34 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Processing
# 2025-03-04 15:48:34 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Fetching Transcript from S3
# 2025-03-04 15:48:34 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:34 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Creating df_intra_call
# 2025-03-04 15:48:44 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Masking PII Data
# 2025-03-04 15:48:45 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Completed Masking PII Data
# 2025-03-04 15:48:45 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Successfully created df_intra_call
# 2025-03-04 15:48:45 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Creating df_inter_call
# 2025-03-04 15:48:47 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Successfully created df_inter_call
# 2025-03-04 15:48:48 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:48 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:48:48 [INFO]: 5066662a-769e-40b7-8985-988de963b8bf: Processed Call #2905 in 0 min 14.13 sec elapsed
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]: dc89c237-67c9-44a5-ba7a-3387db030b37: Call already Processed.
# 2025-03-04 15:48:48 [INFO]: dc89c237-67c9-44a5-ba7a-3387db030b37: Processed Call #2905 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]: 5206bc21-05cb-4e72-bb81-e51523af14b0: Call already Processed.
# 2025-03-04 15:48:48 [INFO]: 5206bc21-05cb-4e72-bb81-e51523af14b0: Processed Call #2905 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]: c6732fea-eedf-412a-ba06-dece211d76d2: Call already Processed.
# 2025-03-04 15:48:48 [INFO]: c6732fea-eedf-412a-ba06-dece211d76d2: Processed Call #2905 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]: 0cbd8147-a633-4a21-8a87-4a8291e57c79: Call already Processed.
# 2025-03-04 15:48:48 [INFO]: 0cbd8147-a633-4a21-8a87-4a8291e57c79: Processed Call #2905 in 0 min 0.01 sec elapsed
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]:
# 2025-03-04 15:48:48 [INFO]: --------------------------
# 2025-03-04 15:48:48 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Processing
# 2025-03-04 15:48:48 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Fetching Transcript from S3
# 2025-03-04 15:48:48 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Successfully fetched the Transcript from S3
# 2025-03-04 15:48:48 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Creating df_intra_call
# 2025-03-04 15:49:04 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Masking PII Data
# 2025-03-04 15:49:05 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Completed Masking PII Data
# 2025-03-04 15:49:05 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Successfully created df_intra_call
# 2025-03-04 15:49:05 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Creating df_inter_call
# 2025-03-04 15:49:08 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Successfully created df_inter_call
# 2025-03-04 15:49:08 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:49:08 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:49:08 [INFO]: 009f064d-ff51-4ed7-b53d-979fdcdc99f3: Processed Call #2906 in 0 min 20.49 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 1add6cd6-639d-4714-84a4-93e8b9d997b9: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 1add6cd6-639d-4714-84a4-93e8b9d997b9: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 58cb5636-5de9-4c96-8fd1-c2f4e50b6954: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 58cb5636-5de9-4c96-8fd1-c2f4e50b6954: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 93300c51-e0c1-4852-84c8-b171036ab2e3: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 93300c51-e0c1-4852-84c8-b171036ab2e3: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 35c859ad-78ae-4147-a100-fce14cea5bad: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 35c859ad-78ae-4147-a100-fce14cea5bad: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 06e09197-fb49-448b-a888-e4f4f7938318: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 06e09197-fb49-448b-a888-e4f4f7938318: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: dc8f4956-9683-452e-b514-960c8132fa0e: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: dc8f4956-9683-452e-b514-960c8132fa0e: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]: 74c51e81-6c96-4235-8082-35f7ccf1b3fa: Call already Processed.
# 2025-03-04 15:49:08 [INFO]: 74c51e81-6c96-4235-8082-35f7ccf1b3fa: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]:
# 2025-03-04 15:49:08 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: c8603fbc-0873-4495-b104-ef847a6b928d: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: c8603fbc-0873-4495-b104-ef847a6b928d: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: c819c59e-ddc7-4e81-8c63-d96da81a064d: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: c819c59e-ddc7-4e81-8c63-d96da81a064d: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: a164b160-9d68-457a-b98d-2c77089b5ec9: Processing
# 2025-03-04 15:49:09 [INFO]: a164b160-9d68-457a-b98d-2c77089b5ec9: Fetching Transcript from S3
# 2025-03-04 15:49:09 [INFO]: a164b160-9d68-457a-b98d-2c77089b5ec9: Successfully fetched the Transcript from S3
# 2025-03-04 15:49:09 [INFO]: a164b160-9d68-457a-b98d-2c77089b5ec9: Creating df_intra_call
# 2025-03-04 15:49:09 [ERROR]: --------------------------
# 2025-03-04 15:49:09 [ERROR]: a164b160-9d68-457a-b98d-2c77089b5ec9: Exception - "None of [Index(['BeginOffsetMillis', 'EndOffsetMillis', 'ParticipantId', 'Content'], dtype='object')] are in the [columns]"
# 2025-03-04 15:49:09 [ERROR]: --------------------------
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 55c1c300-d94b-47d5-a39a-8242db6f248c: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 55c1c300-d94b-47d5-a39a-8242db6f248c: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 8a3dd5fd-8512-45ce-b178-c6039d473cb8: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 8a3dd5fd-8512-45ce-b178-c6039d473cb8: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 0be19a9a-1aca-4a24-b941-08a4f4499a95: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 0be19a9a-1aca-4a24-b941-08a4f4499a95: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 5bbd7c18-61f6-4d04-9c17-abb101a494c6: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 5bbd7c18-61f6-4d04-9c17-abb101a494c6: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: a04ed1b3-fa73-4f50-bfdf-9da573d1e6be: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: a04ed1b3-fa73-4f50-bfdf-9da573d1e6be: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: afcfabea-4f21-4d5c-963d-278c4fe57f4f: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: afcfabea-4f21-4d5c-963d-278c4fe57f4f: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 03c11e3b-7b56-4867-b98b-2b18304ca944: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 03c11e3b-7b56-4867-b98b-2b18304ca944: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 04af6f18-7775-4946-8e5e-5e500e490ee5: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 04af6f18-7775-4946-8e5e-5e500e490ee5: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 5cdf900f-169a-48ca-90b9-7bdd49f03fe7: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 5cdf900f-169a-48ca-90b9-7bdd49f03fe7: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: e289631a-780f-4883-a978-960235ec61d4: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: e289631a-780f-4883-a978-960235ec61d4: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 385ac421-dce5-48d8-8708-0fbb708e4828: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 385ac421-dce5-48d8-8708-0fbb708e4828: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: b2682de1-1562-4c8b-937c-991ee4a5c298: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: b2682de1-1562-4c8b-937c-991ee4a5c298: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: 903fc5f1-9795-4296-ad18-b17a4767eb25: Call already Processed.
# 2025-03-04 15:49:09 [INFO]: 903fc5f1-9795-4296-ad18-b17a4767eb25: Processed Call #2906 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]:
# 2025-03-04 15:49:09 [INFO]: --------------------------
# 2025-03-04 15:49:09 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Processing
# 2025-03-04 15:49:09 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Fetching Transcript from S3
# 2025-03-04 15:49:09 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Successfully fetched the Transcript from S3
# 2025-03-04 15:49:09 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Creating df_intra_call
# 2025-03-04 15:49:29 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Masking PII Data
# 2025-03-04 15:49:29 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Completed Masking PII Data
# 2025-03-04 15:49:29 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Successfully created df_intra_call
# 2025-03-04 15:49:29 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Creating df_inter_call
# 2025-03-04 15:49:32 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Successfully created df_inter_call
# 2025-03-04 15:49:32 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:49:32 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Persisted df_intra_calls_data to CSV.
# 2025-03-04 15:49:32 [INFO]: c2f883e7-b789-43f1-85f6-9f49a3981543: Processed Call #2907 in 0 min 23.40 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: c7a324b6-66f8-428b-a073-b238b0a007af: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: c7a324b6-66f8-428b-a073-b238b0a007af: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: ec6d9885-4c9b-4ed3-9eea-e70928d4b821: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: ec6d9885-4c9b-4ed3-9eea-e70928d4b821: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: bc1e6307-1b60-49aa-8010-be1fbc2620e5: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: bc1e6307-1b60-49aa-8010-be1fbc2620e5: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: d8937a4f-b8c8-4990-9e11-df5892253cc8: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: d8937a4f-b8c8-4990-9e11-df5892253cc8: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: 8e3a7365-8f67-4bb3-82b9-35c2ef5b39a6: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: 8e3a7365-8f67-4bb3-82b9-35c2ef5b39a6: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: 70b9a234-22d8-4709-b9ec-e49ea15ca582: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: 70b9a234-22d8-4709-b9ec-e49ea15ca582: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: f908f7b1-c55d-4919-8d9c-db8f61a26e2a: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: f908f7b1-c55d-4919-8d9c-db8f61a26e2a: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: 4654a3b2-4350-4392-b495-4d53b4864319: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: 4654a3b2-4350-4392-b495-4d53b4864319: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]: 18c3e08a-57f2-467f-aacd-91edac32a649: Call already Processed.
# 2025-03-04 15:49:32 [INFO]: 18c3e08a-57f2-467f-aacd-91edac32a649: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]:
# 2025-03-04 15:49:32 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 06fe864c-f94b-46ef-b617-823d29c56f5f: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 06fe864c-f94b-46ef-b617-823d29c56f5f: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: e83fcecd-5b48-45ad-b3fc-f3b7cb376fe6: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: e83fcecd-5b48-45ad-b3fc-f3b7cb376fe6: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 9083f978-1a57-4681-b050-d7b0f83e8be5: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 9083f978-1a57-4681-b050-d7b0f83e8be5: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: b89e15e4-ea75-46ae-9cca-79f269fcbc88: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: b89e15e4-ea75-46ae-9cca-79f269fcbc88: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 54f6ac4d-75ef-4ef4-940b-a5b000add30f: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 54f6ac4d-75ef-4ef4-940b-a5b000add30f: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 957b8474-3478-4d91-886a-926d6786eeda: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 957b8474-3478-4d91-886a-926d6786eeda: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 82644e5e-8edb-45ec-9427-660648c2f0f6: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 82644e5e-8edb-45ec-9427-660648c2f0f6: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 7bc4d15a-aef1-4e06-8720-e3db0d55ab5e: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 7bc4d15a-aef1-4e06-8720-e3db0d55ab5e: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 4b87d466-9ec3-470c-be20-cd0bf291efe0: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 4b87d466-9ec3-470c-be20-cd0bf291efe0: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: cc37a0fd-40f8-45ae-87e1-569af09002fc: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: cc37a0fd-40f8-45ae-87e1-569af09002fc: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 10b1b3b7-0405-4c4a-a984-9c80a422289b: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 10b1b3b7-0405-4c4a-a984-9c80a422289b: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 05febc83-6615-4de9-870c-fdbf2be089ac: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 05febc83-6615-4de9-870c-fdbf2be089ac: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 3dc4f2c4-25f0-4433-9672-edb688a45f9d: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 3dc4f2c4-25f0-4433-9672-edb688a45f9d: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: efea570b-275f-44d9-808c-be84b22e9a5d: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: efea570b-275f-44d9-808c-be84b22e9a5d: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 050eb713-efce-4199-b159-22922eac3f32: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 050eb713-efce-4199-b159-22922eac3f32: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 18efb580-cd64-494c-ba8c-2221f731bf27: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 18efb580-cd64-494c-ba8c-2221f731bf27: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 3a1d4b84-3b65-4945-89aa-7167c280be99: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 3a1d4b84-3b65-4945-89aa-7167c280be99: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 8c0d8c2c-ded5-4fb0-a134-ac8cf1239b73: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 8c0d8c2c-ded5-4fb0-a134-ac8cf1239b73: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 78afa15b-7b9f-43f7-be8a-ddbe5c529e8b: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 78afa15b-7b9f-43f7-be8a-ddbe5c529e8b: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 594df5cd-b13b-4551-affc-1b831dee0e69: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 594df5cd-b13b-4551-affc-1b831dee0e69: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 5b6e2f6c-f582-44c3-aa47-d8da541c64de: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 5b6e2f6c-f582-44c3-aa47-d8da541c64de: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: f77c5bf7-fc65-492f-8539-f5b79f5dcbba: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: f77c5bf7-fc65-492f-8539-f5b79f5dcbba: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: b141344d-f9f3-4b40-828f-65939c4aefcf: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: b141344d-f9f3-4b40-828f-65939c4aefcf: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 3716c320-5719-4f30-ad39-259913562b92: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 3716c320-5719-4f30-ad39-259913562b92: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: de0ebdca-4d29-4b6a-8150-7bbecace9201: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: de0ebdca-4d29-4b6a-8150-7bbecace9201: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 5d487370-79a8-43d4-9507-dc67184b5ebe: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 5d487370-79a8-43d4-9507-dc67184b5ebe: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 3d92e37e-381e-4206-8a5b-511ea25e2a72: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 3d92e37e-381e-4206-8a5b-511ea25e2a72: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 595d28e7-da03-444a-becf-4eb0402f599d: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 595d28e7-da03-444a-becf-4eb0402f599d: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 2383547e-8e25-4ee5-8680-48d0a649f4ac: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 2383547e-8e25-4ee5-8680-48d0a649f4ac: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 6b3afd60-0abc-4cac-a218-82f51c1db628: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 6b3afd60-0abc-4cac-a218-82f51c1db628: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 3ce4025b-da20-4f67-a214-5f825d43673b: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 3ce4025b-da20-4f67-a214-5f825d43673b: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 173a3cf0-0dcd-44b7-9737-b6830cf11dd7: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 173a3cf0-0dcd-44b7-9737-b6830cf11dd7: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 6da902f5-7513-48db-9a09-cd445d9033bc: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 6da902f5-7513-48db-9a09-cd445d9033bc: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 03ab2108-ddae-447b-92c6-7c1a4a96b67f: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 03ab2108-ddae-447b-92c6-7c1a4a96b67f: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 47c3fa52-f920-4a35-82b7-70ca1addbd29: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 47c3fa52-f920-4a35-82b7-70ca1addbd29: Processed Call #2907 in 0 min 0.01 sec elapsed
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]:
# 2025-03-04 15:49:33 [INFO]: --------------------------
# 2025-03-04 15:49:33 [INFO]: 22f6ccf1-a4e7-49c1-9cd3-04596937552e: Call already Processed.
# 2025-03-04 15:49:33 [INFO]: 22f6ccf1-a4e7-49c1-9cd3-04596937552e: Processed Call #2907 in 0 min 0.01 sec elapsed
# ...
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Processing
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Fetching Transcript from S3
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Creating df_intra_call
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Masking PII Data
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Completed Masking PII Data
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Successfully created df_intra_call
# 2025-03-04 16:17:00 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Creating df_inter_call
# 2025-03-04 16:17:02 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Successfully created df_inter_call
# 2025-03-04 16:17:03 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:03 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:03 [INFO]: 5efc2632-0940-4d27-a0a0-a8bdd6f4a635: Processed Call #3263 in 0 min 3.39 sec elapsed
# 2025-03-04 16:17:03 [INFO]: --------------------------
# 2025-03-04 16:17:03 [INFO]:
# 2025-03-04 16:17:03 [INFO]:
# 2025-03-04 16:17:03 [INFO]: --------------------------
# 2025-03-04 16:17:03 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Processing
# 2025-03-04 16:17:03 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Fetching Transcript from S3
# 2025-03-04 16:17:03 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:03 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Creating df_intra_call
# 2025-03-04 16:17:04 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Masking PII Data
# 2025-03-04 16:17:04 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Completed Masking PII Data
# 2025-03-04 16:17:04 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Successfully created df_intra_call
# 2025-03-04 16:17:04 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Creating df_inter_call
# 2025-03-04 16:17:05 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Successfully created df_inter_call
# 2025-03-04 16:17:06 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:06 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:06 [INFO]: 0d9bc28b-3e30-4048-bb96-1878ddb2e83a: Processed Call #3264 in 0 min 2.97 sec elapsed
# 2025-03-04 16:17:06 [INFO]: --------------------------
# 2025-03-04 16:17:06 [INFO]:
# 2025-03-04 16:17:06 [INFO]:
# 2025-03-04 16:17:06 [INFO]: --------------------------
# 2025-03-04 16:17:06 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Processing
# 2025-03-04 16:17:06 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Fetching Transcript from S3
# 2025-03-04 16:17:06 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:06 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Creating df_intra_call
# 2025-03-04 16:17:07 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Masking PII Data
# 2025-03-04 16:17:07 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Completed Masking PII Data
# 2025-03-04 16:17:07 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Successfully created df_intra_call
# 2025-03-04 16:17:07 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Creating df_inter_call
# 2025-03-04 16:17:09 [ERROR]: Invalid subcategory 'Payment' for category 'Billing'
# 2025-03-04 16:17:09 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Successfully created df_inter_call
# 2025-03-04 16:17:10 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:10 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:10 [INFO]: 3271b22d-15c0-484b-8ce0-11d0d23c02a7: Processed Call #3265 in 0 min 3.94 sec elapsed
# 2025-03-04 16:17:10 [INFO]: --------------------------
# 2025-03-04 16:17:10 [INFO]:
# 2025-03-04 16:17:10 [INFO]:
# 2025-03-04 16:17:10 [INFO]: --------------------------
# 2025-03-04 16:17:10 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Processing
# 2025-03-04 16:17:10 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Fetching Transcript from S3
# 2025-03-04 16:17:10 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:10 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Creating df_intra_call
# 2025-03-04 16:17:20 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Masking PII Data
# 2025-03-04 16:17:20 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Completed Masking PII Data
# 2025-03-04 16:17:20 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Successfully created df_intra_call
# 2025-03-04 16:17:20 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Creating df_inter_call
# 2025-03-04 16:17:23 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Successfully created df_inter_call
# 2025-03-04 16:17:23 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:23 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:23 [INFO]: 26c8565b-c41f-42cf-9d86-d2bd6f0c4b8a: Processed Call #3266 in 0 min 13.22 sec elapsed
# 2025-03-04 16:17:23 [INFO]: --------------------------
# 2025-03-04 16:17:23 [INFO]:
# 2025-03-04 16:17:23 [INFO]:
# 2025-03-04 16:17:23 [INFO]: --------------------------
# 2025-03-04 16:17:23 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Processing
# 2025-03-04 16:17:23 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Fetching Transcript from S3
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Creating df_intra_call
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Masking PII Data
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Completed Masking PII Data
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Successfully created df_intra_call
# 2025-03-04 16:17:24 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Creating df_inter_call
# 2025-03-04 16:17:26 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Successfully created df_inter_call
# 2025-03-04 16:17:26 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:26 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:26 [INFO]: 3d2b8897-069b-4da0-ac81-bcae9cecdc8f: Processed Call #3267 in 0 min 3.02 sec elapsed
# 2025-03-04 16:17:26 [INFO]: --------------------------
# 2025-03-04 16:17:26 [INFO]:
# 2025-03-04 16:17:26 [INFO]:
# 2025-03-04 16:17:26 [INFO]: --------------------------
# 2025-03-04 16:17:26 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Processing
# 2025-03-04 16:17:26 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Fetching Transcript from S3
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Creating df_intra_call
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Masking PII Data
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Completed Masking PII Data
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Successfully created df_intra_call
# 2025-03-04 16:17:27 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Creating df_inter_call
# 2025-03-04 16:17:29 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Successfully created df_inter_call
# 2025-03-04 16:17:29 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:29 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:29 [INFO]: 3d534673-bd16-42a8-9ced-c9d742166c90: Processed Call #3268 in 0 min 3.08 sec elapsed
# 2025-03-04 16:17:29 [INFO]: --------------------------
# 2025-03-04 16:17:29 [INFO]:
# 2025-03-04 16:17:29 [INFO]:
# 2025-03-04 16:17:29 [INFO]: --------------------------
# 2025-03-04 16:17:29 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Processing
# 2025-03-04 16:17:29 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Fetching Transcript from S3
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Creating df_intra_call
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Masking PII Data
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Completed Masking PII Data
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Successfully created df_intra_call
# 2025-03-04 16:17:30 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Creating df_inter_call
# 2025-03-04 16:17:32 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Successfully created df_inter_call
# 2025-03-04 16:17:32 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:32 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:32 [INFO]: 1877a94f-2f9a-492e-aaa9-cef2017c7f78: Processed Call #3269 in 0 min 2.88 sec elapsed
# 2025-03-04 16:17:32 [INFO]: --------------------------
# 2025-03-04 16:17:32 [INFO]:
# 2025-03-04 16:17:32 [INFO]:
# 2025-03-04 16:17:32 [INFO]: --------------------------
# 2025-03-04 16:17:32 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Processing
# 2025-03-04 16:17:32 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Fetching Transcript from S3
# 2025-03-04 16:17:33 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:33 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Creating df_intra_call
# 2025-03-04 16:17:37 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Masking PII Data
# 2025-03-04 16:17:37 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Completed Masking PII Data
# 2025-03-04 16:17:37 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Successfully created df_intra_call
# 2025-03-04 16:17:37 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Creating df_inter_call
# 2025-03-04 16:17:39 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Successfully created df_inter_call
# 2025-03-04 16:17:40 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:40 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:40 [INFO]: 07db5988-4c56-41af-958d-b6d2d113cf11: Processed Call #3270 in 0 min 7.68 sec elapsed
# 2025-03-04 16:17:40 [INFO]: --------------------------
# 2025-03-04 16:17:40 [INFO]:
# 2025-03-04 16:17:40 [INFO]:
# 2025-03-04 16:17:40 [INFO]: --------------------------
# 2025-03-04 16:17:40 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Processing
# 2025-03-04 16:17:40 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Fetching Transcript from S3
# 2025-03-04 16:17:40 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:40 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Creating df_intra_call
# 2025-03-04 16:17:40 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Masking PII Data
# 2025-03-04 16:17:41 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Completed Masking PII Data
# 2025-03-04 16:17:41 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Successfully created df_intra_call
# 2025-03-04 16:17:41 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Creating df_inter_call
# 2025-03-04 16:17:42 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Successfully created df_inter_call
# 2025-03-04 16:17:43 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:43 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:43 [INFO]: 25cee0a7-28c2-4c0b-a002-89ed5fce0084: Processed Call #3271 in 0 min 3.08 sec elapsed
# 2025-03-04 16:17:43 [INFO]: --------------------------
# 2025-03-04 16:17:43 [INFO]:
# 2025-03-04 16:17:43 [INFO]:
# 2025-03-04 16:17:43 [INFO]: --------------------------
# 2025-03-04 16:17:43 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Processing
# 2025-03-04 16:17:43 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Fetching Transcript from S3
# 2025-03-04 16:17:43 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:43 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Creating df_intra_call
# 2025-03-04 16:17:43 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Masking PII Data
# 2025-03-04 16:17:44 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Completed Masking PII Data
# 2025-03-04 16:17:44 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Successfully created df_intra_call
# 2025-03-04 16:17:44 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Creating df_inter_call
# 2025-03-04 16:17:45 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Successfully created df_inter_call
# 2025-03-04 16:17:46 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:46 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:46 [INFO]: 03c6cad2-8900-4b2b-961c-3adcaeef9e40: Processed Call #3272 in 0 min 3.08 sec elapsed
# 2025-03-04 16:17:46 [INFO]: --------------------------
# 2025-03-04 16:17:46 [INFO]:
# 2025-03-04 16:17:46 [INFO]:
# 2025-03-04 16:17:46 [INFO]: --------------------------
# 2025-03-04 16:17:46 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Processing
# 2025-03-04 16:17:46 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Fetching Transcript from S3
# 2025-03-04 16:17:46 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:46 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Creating df_intra_call
# 2025-03-04 16:17:47 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Masking PII Data
# 2025-03-04 16:17:47 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Completed Masking PII Data
# 2025-03-04 16:17:47 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Successfully created df_intra_call
# 2025-03-04 16:17:47 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Creating df_inter_call
# 2025-03-04 16:17:49 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Successfully created df_inter_call
# 2025-03-04 16:17:49 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:49 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:49 [INFO]: 1f6e9d8a-6363-4f83-a9c6-c7404d9793e6: Processed Call #3273 in 0 min 3.20 sec elapsed
# 2025-03-04 16:17:49 [INFO]: --------------------------
# 2025-03-04 16:17:49 [INFO]:
# 2025-03-04 16:17:49 [INFO]:
# 2025-03-04 16:17:49 [INFO]: --------------------------
# 2025-03-04 16:17:49 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Processing
# 2025-03-04 16:17:49 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Fetching Transcript from S3
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Successfully fetched the Transcript from S3
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Creating df_intra_call
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Masking PII Data
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Completed Masking PII Data
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Successfully created df_intra_call
# 2025-03-04 16:17:50 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Creating df_inter_call
# 2025-03-04 16:17:52 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Successfully created df_inter_call
# 2025-03-04 16:17:52 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:52 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Persisted df_intra_calls_data to CSV.
# 2025-03-04 16:17:52 [INFO]: 4ea86a75-885c-4e7c-9524-bca5497bdb1e: Processed Call #3274 in 0 min 2.94 sec elapsed
# 2025-03-04 16:17:52 [INFO]: --------------------------
# 2025-03-04 16:17:52 [INFO]:
# 2025-03-04 16:17:52 [INFO]:

# %% [markdown]
# # Validate

# %%
len(df_inter_calls_data)
# Out:
# 3274

# %%
# df_intra_calls_data[df_intra_calls_data.CONTACT_ID == df_inter_calls_data.CONTACT_ID[96]]

# %%
len(df_list_transcripts)
# Out:
# 3348

# %%
len(df_list_transcripts) - len(df_inter_calls_data)
# Out:
# 74
