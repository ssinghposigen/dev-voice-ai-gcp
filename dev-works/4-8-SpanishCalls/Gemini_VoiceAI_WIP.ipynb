# %% [markdown]
# # 1. Imports

# %%
import os, time, re, ast
import numpy as np
from datetime import timedelta, datetime
import pandas as pd, json
from scipy.special import softmax

import logging
# logging.basicConfig(level=logging.INFO)
# Configure basic logging with INFO level and write to a file
logging.basicConfig(filename='geminie_info.log', level=logging.INFO, format='%(asctime)s %(levelname)s %(message)s')
# logging.basicConfig(level=logging.WARNING)

from google.cloud import bigquery, storage

import vertexai
from vertexai.generative_models import GenerativeModel, Part, FinishReason
import vertexai.preview.generative_models as generative_models


# Sentiments
from transformers import pipeline
from transformers import AutoTokenizer, AutoConfig
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification


# Shap Significance
import shap

# %% [markdown]
# # 2. Variables

# %%
# Environment
project="eid-dw-dev-a5cf"

location="us-central1"

bucket_name="tte-eid-d-gcs-service-desk-call-recordings"

vertexai.init(project="eid-dw-dev-a5cf", location="us-central1")

# Gemini Model
model = GenerativeModel("gemini-1.5-pro-preview-0409")

# generation_config = {
#     "temperature": 0,
#     "top_p": 0.95,
# }

# safety_settings = {
#     generative_models.HarmCategory.HARM_CATEGORY_HATE_SPEECH: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
#     generative_models.HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
#     generative_models.HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
#     generative_models.HarmCategory.HARM_CATEGORY_HARASSMENT: generative_models.HarmBlockThreshold.BLOCK_MEDIUM_AND_ABOVE,
# }

# Audio Files
# uris = [
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Ujet/ujet-voice-recordings_call-279902.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Ujet/ujet-voice-recordings_call-2807561.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Ujet/ujet-voice-recordings_call-281491.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240327-150827_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-121307_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-131703_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-142841_Recording.mp3",    
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-151417_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-162135_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-165108_Recording.mp3",
#     "gs://tte-eid-d-gcs-mlops-users-files/VoiceAI/Calls/GMT20240328-184817_Recording.mp3",    
# ]

# %% [markdown]
# # 3. Util Functions

# %% [markdown]
# #### Audio Converter

# %%
# to conver m4a files to mp3

# import pydub

# # Load the m4a file
# fileLoc = '/home/jupyter/VoiceAI/calls/GMT20240328-184817_Recording.m4a'
# m4a_file = pydub.AudioSegment.from_file(fileLoc)

# # Export the audio file as mp3
# m4a_file.export('/home/jupyter/VoiceAI/calls/GMT20240328-184817_Recording.mp3', format="mp3")

# %% [markdown]
# #### Get Calls audio from GCS bucket

# %%
def get_calls_from_gcs_bucket(bucket_name):
    files = {}
    """Lists all the blobs in the bucket."""
    # bucket_name = "your-bucket-name"

    storage_client = storage.Client()

    # Note: Client.list_blobs requires at least package version 1.17.0.
    blobs = storage_client.list_blobs(bucket_name)

    # get files between 2 and 10 MB
    for blob in blobs:
        if round(blob.size/(1024 * 1024), 2)> 2.00 and round(blob.size/(1024 * 1024), 2) < 60.00:
            files["gs://"+bucket_name+"/"+blob.name] = round(blob.size/(1024 * 1024), 2)
    return files
logging.info("Function: To read calls from GCS Bucket: get_calls_from_gcs_bucket()")

uris = get_calls_from_gcs_bucket(bucket_name)
list(uris.keys())[:5]
# Out:
# ['gs://tte-eid-d-gcs-service-desk-call-recordings/ujet-voice-recordings/call-1.wav',
#  'gs://tte-eid-d-gcs-service-desk-call-recordings/ujet-voice-recordings/call-1000.wav',
#  'gs://tte-eid-d-gcs-service-desk-call-recordings/ujet-voice-recordings/call-10000.wav',
#  'gs://tte-eid-d-gcs-service-desk-call-recordings/ujet-voice-recordings/call-100000.wav',
#  'gs://tte-eid-d-gcs-service-desk-call-recordings/ujet-voice-recordings/call-100002.wav']

# %% [markdown]
# #### initiate_master_dataframes

# %%
def initiate_master_dataframes():
    if os.path.isfile("df_intra_calls_data.csv"):
        df_intra_calls_data = pd.read_csv("df_intra_calls_data.csv")
        df_intra_calls_data.call_id = df_intra_calls_data.call_id.astype('string')
        logging.info("Read data from existing - df_intra_calls_data.")
    else:
        df_intra_calls_data = pd.DataFrame()
        logging.info("Initiated null DataFrame: df_intra_calls_data")


    if os.path.isfile("df_inter_calls_data.csv"):
        df_inter_calls_data = pd.read_csv("df_inter_calls_data.csv")
        df_inter_calls_data.call_id = df_inter_calls_data.call_id.astype('string')
        logging.info("Read data from existing - df_inter_calls_data.")
    else:
        df_inter_calls_data = pd.DataFrame()
        logging.info("Initiated null DataFrame: df_inter_calls_data")
        
    return df_intra_calls_data, df_inter_calls_data
logging.info("Function: To initiate Master DataFrame: initiate_master_dataframes()")

# %% [markdown]
# #### generate_resp_from_transcript

# %%
def generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt, transcript):
    logging.info("Started: "+task)
    responses = model.generate_content(
        [prompt, transcript],
        generation_config=generation_config,
        # safety_settings=safety_settings,
        stream=True
    )
    
    text_list = []
    for response in responses:
        text_list.append(response.text)
    logging.info(text_list[:100])
    logging.info("Completed: "+task)
    return text_list
logging.info("Function: To get Gemini response from Call Transcript: generate_resp_from_transcript()")

# %% [markdown]
# #### generate_resp_from_audio

# %%
def generate_resp_from_audio(model, task, prompt, uri):
    audio = Part.from_uri(
        mime_type="audio/wav",
        uri=uri
    )

    logging.info("Started: "+task)
    response = model.generate_content(
        [prompt, audio]
    )
    
    logging.info(response.text.splitlines()[:10])
    return response.text.splitlines()
logging.info("Function: To get Gemini response from Call Audio: generate_resp_from_audio()")

# %% [markdown]
# #### convert_transcript_to_df

# %%
def convert_transcript_to_df(text_list):
    # Split each line into a list of elements
    data_list = []
    for line in text_list:
        elements = line.split(",")
        if len(elements) == 5:
            data_list.append({
                "start": elements[0],
                "end": elements[1],
                "speaker": elements[2],
                "speaker_label": elements[3],
                "text": elements[4]
            })

    # Create DataFrame from list of dictionaries
    df_transcription = pd.DataFrame(data_list)
    logging.info("Completed DataFrame creation of transcription.")
    return df_transcription
logging.info("Function: Convert Transcript to Dataframe: convert_transcript_to_df()")

# %% [markdown]
# #### process_call

# %%
def process_call(model, transcript_prompt, uri, call_id, df_intra_calls_data, df_inter_calls_data):
    logging.info("Processing call.")
    start = time.time()
    task = "generate transcript."
    text_list = generate_resp_from_audio(model, task, transcript_prompt, uri)
    end = time.time()
    logging.info("Time to transcribe calls "+call_id+": "+str(timedelta(seconds=end-start)))
    df_intra_call = convert_transcript_to_df(text_list)
    df_intra_call.insert(loc=0, column='call_id', value=call_id)

    logging.info("Creating inter-call DataFrame.")
    df_inter_call = pd.DataFrame()
    df_inter_call['call_id'] = [call_id]
    df_inter_call['call_uri'] = uri
    df_inter_call['call_text'] = " ".join(df_intra_call.text)
    logging.info("Completed adding Call Conversationg full text.")


    # Appending to Intra-calls Master DataFrame
    df_intra_calls_data = pd.concat([df_intra_calls_data, df_intra_call], ignore_index=True)
    logging.info("Completed appending to Intra-calls Master DataFrame.")

    df_intra_calls_data.to_csv("df_intra_calls_data.csv", index=False)
    logging.info("Completed Persisting df_intra_calls_data with "+str(call_id)+" to CSV.")

    # Appending to Inter-calls Master DataFrame
    df_inter_calls_data = pd.concat([df_inter_calls_data, df_inter_call], ignore_index=True)
    logging.info("Completed appended to Inter-calls Master DataFrame.")

    df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
    logging.info("Completed Persisting df_inter_calls_data Dataframe to CSV.")
    logging.info("----              ")
    logging.info("----              ")
logging.info("Function: to process calls: process_call()")

# %% [markdown]
# #### get_sentiment_label

# %%
def get_sentiment_label(row):
  # Check conditions in order of priority (Positive > Negative > Neutral)
  if row['positive'] > row['negative'] and row['positive'] > row['neutral']:
    return 'POSITIVE'
  elif row['negative'] > row['positive'] and row['negative'] > row['neutral']:
    return 'NEGATIVE'
  else:
    return 'NEUTRAL'
logging.info("Function: To get Sentiment Label for the text: get_sentiment_label()")

# %%
def get_shap_word_importance(explainer,text):
    try:
        shap_values = explainer([text],fixed_context=1)[0]
        word_imp=get_word_imp(shap_values)
        result={'WordImportance':word_imp}
        return result
    except Exception as e:
        print('run time error',str(e))
logging.info("Function: To get Shap Word Importance: get_shap_word_importance()")

# %%
def preprocess_text(text):
    prcsd_text = text.lower()
    prcsd_text = prcsd_text.translate(str.maketrans('', '', string.punctuation))
    prcsd_text = " ".join([word for word in str(prcsd_text).split() if word not in STOPWORDS])
    return prcsd_text
logging.info("Function: To preprocess text: preprocess_text()")

# %%
def get_word_imp(shapV):
    result = []
    for word, nums in zip(shapV.data, shapV.values):
        result.append({'SentimentWord': word,'SentimentWordImportanceNegative': nums[0],'SentimentWordImportancePositive': nums[1]})
    return result
logging.info("Function: To get word level significance: get_word_imp()")

# %%
def create_sorted_words_df(data_str):
    # Use ast.literal_eval to safely convert the string to a list
    data_list = ast.literal_eval(data_str)

    # Create DataFrames for positive and negative words
    df_positive = pd.DataFrame(data_list)[['SentimentWord', 'SentimentWordImportancePositive']]
    df_negative = pd.DataFrame(data_list)[['SentimentWord', 'SentimentWordImportanceNegative']]

    # Sort by importance (descending order) and select top 3
    top_positive_words = df_positive.sort_values(by='SentimentWordImportancePositive', ascending=False).head(3)['SentimentWord'].tolist()
    top_negative_words = df_negative.sort_values(by='SentimentWordImportanceNegative', ascending=False).head(3)['SentimentWord'].tolist()

    # Create the DataFrame with desired columns
    data = {
        'MaxPositiveSentimentWord': top_positive_words[0],
        'MaxPositiveSentimentWord2': top_positive_words[1],
        'MaxPositiveSentimentWord3': top_positive_words[2],
        'MaxNegativeSentimentWord': top_negative_words[0],
        'MaxNegativeSentimentWord2': top_negative_words[1],
        'MaxNegativeSentimentWord3': top_negative_words[2]
    }
    return data
logging.info("Function: To create dictionary of shap value sorted words: process_call()")

# %% [markdown]
# # 5. Transcribing Calls

# %%
prompt_transcript="""
Transcribe this audio file, in the comma separated format: start,end,speaker,speaker_label,caption.
00:05,00:07,speaker name,System,caption
00:05,00:07,speaker name,Employee,caption
00:05,00:07,speaker name,Agent,caption
00:05,00:07,speaker name,Employee,caption
"""

# %% [markdown]
# ### Without Retry

# %%
masterstart = time.time()
process = "transcribing"
for uri in uris:
    # if uri.split("/")[-1].startswith('GMT'):
    #     call_id = uri.split("/")[-1].split("-")[1].split("_")[0]
    # elif uri.split("/")[-1].startswith('ujet'):
    #     call_id = uri.split("/")[-1].split("_")[1].split("-")[1].split(".")[0]
    logging.info(uri)
    call_id = uri.split("-")[-1].split(".")[0]
    logging.info("Started processing call: "+str(call_id))
    print(("Started processing call: "+str(call_id)))
    
    # Initiating Master DataFrames
    df_intra_calls_data, df_inter_calls_data = initiate_master_dataframes()
    
    # Check if DataFrame exists in Memory
    if len(df_intra_calls_data) > 0:
        # Check if Call is already Processed
        if call_id in df_intra_calls_data.call_id.unique():
            logging.info("Call already Processed.")
            logging.info("                                         ")
            logging.info("                                         ")
        else:
            logging.info("Processing call.")
            process_call(model, prompt_transcript, uri, call_id, df_intra_calls_data, df_inter_calls_data)
            logging.info("Completed processing call.")
            # logging.info("Sleeping for 5 mins.")
            # time.sleep(5 * 60)
            
    else:
        logging.info("Processing call.")
        process_call(model, prompt_transcript, uri, call_id, df_intra_calls_data, df_inter_calls_data)
        logging.info("Completed processing call.")
        # logging.info("Sleeping for 5 mins.")
        # time.sleep(5 * 60)
    
masterend = time.time()
logging.info("Time to Process all calls "+str(len(uris))+": "+str(timedelta(seconds=masterend-masterstart)))
# Out:
# Started processing call: 1
# Started processing call: 1000
# Started processing call: 10000
# Started processing call: 100000
# Started processing call: 100002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 25
#      23     else:
#      24         logging.info("Processing call.")
# ---> 25         process_call(model, prompt_transcript, uri, call_id, df_intra_calls_data, df_inter_calls_data)
#      26         logging.info("Completed processing call.")
#      27         # logging.info("Sleeping for 5 mins.")
#      28         # time.sleep(5 * 60)
#      29
#      30 else:
#
# Cell In[37], line 5, in process_call(model, transcript_prompt, uri, call_id, df_intra_calls_data, df_inter_calls_data)
#       3 start = time.time()
#       4 task = "generate transcript."
# ----> 5 text_list = generate_resp_from_audio(model, task, transcript_prompt, uri)
#       6 end = time.time()
#       7 logging.info("Time to transcribe calls "+call_id+": "+str(timedelta(seconds=end-start)))
#
# Cell In[23], line 8, in generate_resp_from_audio(model, task, prompt, uri)
#       2 audio = Part.from_uri(
#       3     mime_type="audio/wav",
#       4     uri=uri
#       5 )
#       7 logging.info("Started: "+task)
# ----> 8 response = model.generate_content(
#       9     [prompt, audio]
#      10 )
#      12 logging.info(response.text.splitlines()[:10])
#      13 return response.text.splitlines()
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:405, in _GenerativeModel.generate_content(self, contents, generation_config, safety_settings, tools, tool_config, stream)
#     397     return self._generate_content_streaming(
#     398         contents=contents,
#     399         generation_config=generation_config,
#    (...)
#     402         tool_config=tool_config,
#     403     )
#     404 else:
# --> 405     return self._generate_content(
#     406         contents=contents,
#     407         generation_config=generation_config,
#     408         safety_settings=safety_settings,
#     409         tools=tools,
#     410         tool_config=tool_config,
#     411     )
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/vertexai/generative_models/_generative_models.py:494, in _GenerativeModel._generate_content(self, contents, generation_config, safety_settings, tools, tool_config)
#     469 """Generates content.
#     470
#     471 Args:
#    (...)
#     485     A single GenerationResponse object
#     486 """
#     487 request = self._prepare_request(
#     488     contents=contents,
#     489     generation_config=generation_config,
#    (...)
#     492     tool_config=tool_config,
#     493 )
# --> 494 gapic_response = self._prediction_client.generate_content(request=request)
#     495 return self._parse_response(gapic_response)
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/google/cloud/aiplatform_v1beta1/services/prediction_service/client.py:2102, in PredictionServiceClient.generate_content(self, request, model, contents, retry, timeout, metadata)
#    2099 self._validate_universe_domain()
#    2101 # Send the request.
# -> 2102 response = rpc(
#    2103     request,
#    2104     retry=retry,
#    2105     timeout=timeout,
#    2106     metadata=metadata,
#    2107 )
#    2109 # Done; return the response.
#    2110 return response
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/google/api_core/gapic_v1/method.py:131, in _GapicCallable.__call__(self, timeout, retry, compression, *args, **kwargs)
#     128 if self._compression is not None:
#     129     kwargs["compression"] = compression
# --> 131 return wrapped_func(*args, **kwargs)
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/google/api_core/grpc_helpers.py:76, in _wrap_unary_errors.<locals>.error_remapped_callable(*args, **kwargs)
#      73 @functools.wraps(callable_)
#      74 def error_remapped_callable(*args, **kwargs):
#      75     try:
# ---> 76         return callable_(*args, **kwargs)
#      77     except grpc.RpcError as exc:
#      78         raise exceptions.from_grpc_error(exc) from exc
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/grpc/_channel.py:1173, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def __call__(
#    1162     self,
#    1163     request: Any,
#    (...)
#    1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Any:
#    1170     (
#    1171         state,
#    1172         call,
# -> 1173     ) = self._blocking(
#    1174         request, timeout, metadata, credentials, wait_for_ready, compression
#    1175     )
#    1176     return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/grpc/_channel.py:1157, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1141 state.target = _common.decode(self._target)
#    1142 call = self._channel.segregated_call(
#    1143     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1144     self._method,
#    (...)
#    1155     self._context,
#    1156 )
# -> 1157 event = call.next_event()
#    1158 _handle_event(event, state, self._response_deserializer)
#    1159 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:367, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:188, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:182, in grpc._cython.cygrpc._next_call_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:78, in grpc._cython.cygrpc._latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:61, in grpc._cython.cygrpc._internal_latent_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/completion_queue.pyx.pxi:42, in grpc._cython.cygrpc._next()
#
# KeyboardInterrupt:

# %% [markdown]
# ### With Retry

# %%
processed_calls = []
exceptioned_calls = {}

# %%
exceptioned_calls
# Out:
# {}

# %%
# def try_call_processing():
masterstart = time.time()
process = "transcribing"
for uri in uris:
    # if uri.split("/")[-1].startswith('GMT'):
    #     call_id = uri.split("/")[-1].split("-")[1].split("_")[0]
    # elif uri.split("/")[-1].startswith('ujet'):
    #     call_id = uri.split("/")[-1].split("_")[1].split("-")[1].split(".")[0]
    logging.info(uri)
    call_id = uri.split("-")[-1].split(".")[0]
    if call_id not in exceptioned_calls.keys():

        try:
            logging.info("Started processing call: "+str(call_id))
            print("Started processing call: "+str(call_id))

            # Initiating Master DataFrames
            df_intra_calls_data, df_inter_calls_data = initiate_master_dataframes()

            # Check if DataFrame exists in Memory
            if len(df_intra_calls_data) > 0:
                # Check if Call is already Processed
                if call_id in df_intra_calls_data.call_id.unique():
                    print("Call already Processed.")
                    logging.info("Call already Processed.")
                    logging.info("                                         ")
                    logging.info("                                         ")
                else:
                    logging.info("Processing call.")
                    process_call(model, generation_config, safety_settings, transcript_prompt, uri, call_id, df_intra_calls_data, df_inter_calls_data)
                    processed_calls.append(call_id)
                    logging.info("Completed processing call.")
                    print("Completed processing call.")
                    # logging.info("Sleeping for 5 mins.")
                    # time.sleep(5 * 60)

            else:
                logging.info("Processing call.")
                process_call(model, generation_config, safety_settings, transcript_prompt, uri, call_id, df_intra_calls_data, df_inter_calls_data)
                logging.info("Completed processing call.")
                print("Completed processing call.")
                # logging.info("Sleeping for 5 mins.")
                # time.sleep(5 * 60)

        except Exception as e:
            # exceptioned_calls.append({call_id: e})
            exceptioned_calls[call_id] = e
            logging.info("Cautght Exception: "+str(call_id))
            print("Cautght Exception: "+str(call_id))

masterend = time.time()
logging.info("Time to Process all calls "+str(len(uris))+": "+str(timedelta(seconds=masterend-masterstart)))
# Out:
# Started processing call: 1
# Cautght Exception: 1
# Started processing call: 1000
# Cautght Exception: 1000
# Started processing call: 10000
# Cautght Exception: 10000
# Started processing call: 100000
# Cautght Exception: 100000
# Started processing call: 100002
# Cautght Exception: 100002
# Started processing call: 100003
# Cautght Exception: 100003
# Started processing call: 100004
# Cautght Exception: 100004
# Started processing call: 100007
# Cautght Exception: 100007
# Started processing call: 10001
# Cautght Exception: 10001
# Started processing call: 100011
# Cautght Exception: 100011
# Started processing call: 100012
# Cautght Exception: 100012
# Started processing call: 100013
# Cautght Exception: 100013
# Started processing call: 100015
# Cautght Exception: 100015
# Started processing call: 100017
# Cautght Exception: 100017
# Started processing call: 100019
# Cautght Exception: 100019
# Started processing call: 100021
# Cautght Exception: 100021
# Started processing call: 100024
# Cautght Exception: 100024
# Started processing call: 100025
# Cautght Exception: 100025
# Started processing call: 100026
# Cautght Exception: 100026
# Started processing call: 100028
# Cautght Exception: 100028
# Started processing call: 100029
# Cautght Exception: 100029
# Started processing call: 100030
# Cautght Exception: 100030
# Started processing call: 100031
# Cautght Exception: 100031
# Started processing call: 100032
# Cautght Exception: 100032
# Started processing call: 100033
# Cautght Exception: 100033
# Started processing call: 100034
# Cautght Exception: 100034
# Started processing call: 100035
# Cautght Exception: 100035
# Started processing call: 100036
# Cautght Exception: 100036
# Started processing call: 100040
# Cautght Exception: 100040
# Started processing call: 100041
# Cautght Exception: 100041
# Started processing call: 100043
# Cautght Exception: 100043
# Started processing call: 100044
# Cautght Exception: 100044
# Started processing call: 100045
# Cautght Exception: 100045
# Started processing call: 100047
# Cautght Exception: 100047
# Started processing call: 100048
# Cautght Exception: 100048
# Started processing call: 100049
# Cautght Exception: 100049
# Started processing call: 10005
# Cautght Exception: 10005
# Started processing call: 100051
# Cautght Exception: 100051
# Started processing call: 100052
# Cautght Exception: 100052
# Started processing call: 100055
# Cautght Exception: 100055
# Started processing call: 10006
# Cautght Exception: 10006
# Started processing call: 100062
# Cautght Exception: 100062
# Started processing call: 100064
# Cautght Exception: 100064
# Started processing call: 100065
# Cautght Exception: 100065
# Started processing call: 100067
# Cautght Exception: 100067
# Started processing call: 100068
# Cautght Exception: 100068
# Started processing call: 100069
# Cautght Exception: 100069
# Started processing call: 10007
# Cautght Exception: 10007
# Started processing call: 100070
# Cautght Exception: 100070
# Started processing call: 100072
# Cautght Exception: 100072
# Started processing call: 100073
# Cautght Exception: 100073
# Started processing call: 100077
# Cautght Exception: 100077
# Started processing call: 100078
# Cautght Exception: 100078
# Started processing call: 100079
# Cautght Exception: 100079
# Started processing call: 10008
# Cautght Exception: 10008
# Started processing call: 100085
# Cautght Exception: 100085
# Started processing call: 100086
# Cautght Exception: 100086
# Started processing call: 100087
# Cautght Exception: 100087
# Started processing call: 100089
# Cautght Exception: 100089
# Started processing call: 10009
# Cautght Exception: 10009
# Started processing call: 100090
# Cautght Exception: 100090
# Started processing call: 100091
# Cautght Exception: 100091
# Started processing call: 100098
# Cautght Exception: 100098
# Started processing call: 100099
# Cautght Exception: 100099
# Started processing call: 1001
# Cautght Exception: 1001
# Started processing call: 100100
# Cautght Exception: 100100
# Started processing call: 100104
# Cautght Exception: 100104
# Started processing call: 100105
# Cautght Exception: 100105
# Started processing call: 100106
# Cautght Exception: 100106
# Started processing call: 100107
# Cautght Exception: 100107
# Started processing call: 100108
# Cautght Exception: 100108
# Started processing call: 10011
# Cautght Exception: 10011
# Started processing call: 100110
# Cautght Exception: 100110
# Started processing call: 100111
# Cautght Exception: 100111
# Started processing call: 100112
# Cautght Exception: 100112
# Started processing call: 100116
# Cautght Exception: 100116
# Started processing call: 100119
# Cautght Exception: 100119
# Started processing call: 10012
# Cautght Exception: 10012
# Started processing call: 100121
# Cautght Exception: 100121
# Started processing call: 100122
# Cautght Exception: 100122
# Started processing call: 100124
# Cautght Exception: 100124
# Started processing call: 100125
# Cautght Exception: 100125
# Started processing call: 10013
# Cautght Exception: 10013
# Started processing call: 100134
# Cautght Exception: 100134
# Started processing call: 100136
# Cautght Exception: 100136
# Started processing call: 100138
# Cautght Exception: 100138
# Started processing call: 10014
# Cautght Exception: 10014
# Started processing call: 100143
# Cautght Exception: 100143
# Started processing call: 100147
# Cautght Exception: 100147
# Started processing call: 100154
# Cautght Exception: 100154
# Started processing call: 100155
# Cautght Exception: 100155
# Started processing call: 100156
# Cautght Exception: 100156
# Started processing call: 100162
# Cautght Exception: 100162
# Started processing call: 100164
# Cautght Exception: 100164
# Started processing call: 100165
# Cautght Exception: 100165
# Started processing call: 100167
# Cautght Exception: 100167
# Started processing call: 100171
# Cautght Exception: 100171
# Started processing call: 100174
# Cautght Exception: 100174
# Started processing call: 100175
# Cautght Exception: 100175
# Started processing call: 100176
# Cautght Exception: 100176
# Started processing call: 100179
# Cautght Exception: 100179
# Started processing call: 100180
# Cautght Exception: 100180
# Started processing call: 100181
# Cautght Exception: 100181
# Started processing call: 100185
# Cautght Exception: 100185
# Started processing call: 100188
# Cautght Exception: 100188
# Started processing call: 100189
# Cautght Exception: 100189
# Started processing call: 100191
# Cautght Exception: 100191
# Started processing call: 100192
# Cautght Exception: 100192
# Started processing call: 100193
# Cautght Exception: 100193
# Started processing call: 100194
# Cautght Exception: 100194
# Started processing call: 100196
# Cautght Exception: 100196
# Started processing call: 100197
# Cautght Exception: 100197
# Started processing call: 1002
# Cautght Exception: 1002
# Started processing call: 10020
# Cautght Exception: 10020
# Started processing call: 100200
# Cautght Exception: 100200
# Started processing call: 100201
# Cautght Exception: 100201
# Started processing call: 100205
# Cautght Exception: 100205
# Started processing call: 100206
# Cautght Exception: 100206
# Started processing call: 100210
# Cautght Exception: 100210
# Started processing call: 100215
# Cautght Exception: 100215
# Started processing call: 100217
# Cautght Exception: 100217
# Started processing call: 10022
# Cautght Exception: 10022
# Started processing call: 100227
# Cautght Exception: 100227
# Started processing call: 100228
# Cautght Exception: 100228
# Started processing call: 100230
# Cautght Exception: 100230
# Started processing call: 100232
# Cautght Exception: 100232
# Started processing call: 100236
# Cautght Exception: 100236
# Started processing call: 100237
# Cautght Exception: 100237
# Started processing call: 100238
# Cautght Exception: 100238
# Started processing call: 10024
# Cautght Exception: 10024
# Started processing call: 100240
# Cautght Exception: 100240
# Started processing call: 100242
# Cautght Exception: 100242
# Started processing call: 100243
# Cautght Exception: 100243
# Started processing call: 100244
# Cautght Exception: 100244
# Started processing call: 100245
# Cautght Exception: 100245
# Started processing call: 100251
# Cautght Exception: 100251
# Started processing call: 100252
# Cautght Exception: 100252
# Started processing call: 100253
# Cautght Exception: 100253
# Started processing call: 100256
# Cautght Exception: 100256
# Started processing call: 100257
# Cautght Exception: 100257
# Started processing call: 100260
# Cautght Exception: 100260
# Started processing call: 100262
# Cautght Exception: 100262
# Started processing call: 100264
# Cautght Exception: 100264
# Started processing call: 100266
# Cautght Exception: 100266
# Started processing call: 100269
# Cautght Exception: 100269
# Started processing call: 100271
# Cautght Exception: 100271
# Started processing call: 100272
# Cautght Exception: 100272
# Started processing call: 100276
# Cautght Exception: 100276
# Started processing call: 100279
# Cautght Exception: 100279
# Started processing call: 10028
# Cautght Exception: 10028
# Started processing call: 100281
# Cautght Exception: 100281
# Started processing call: 100282
# Cautght Exception: 100282
# Started processing call: 100284
# Cautght Exception: 100284
# Started processing call: 100286
# Cautght Exception: 100286
# Started processing call: 100287
# Cautght Exception: 100287
# Started processing call: 100290
# Cautght Exception: 100290
# Started processing call: 100291
# Cautght Exception: 100291
# Started processing call: 100293
# Cautght Exception: 100293
# Started processing call: 100294
# Cautght Exception: 100294
# Started processing call: 100297
# Cautght Exception: 100297
# Started processing call: 100299
# Cautght Exception: 100299
# Started processing call: 100300
# Cautght Exception: 100300
# Started processing call: 100301
# Cautght Exception: 100301
# Started processing call: 100303
# Cautght Exception: 100303
# Started processing call: 100305
# Cautght Exception: 100305
# Started processing call: 100308
# Cautght Exception: 100308
# Started processing call: 100312
# Cautght Exception: 100312
# Started processing call: 100313
# Cautght Exception: 100313
# Started processing call: 100317
# Cautght Exception: 100317
# Started processing call: 100318
# Cautght Exception: 100318
# Started processing call: 100319
# Cautght Exception: 100319
# Started processing call: 100320
# Cautght Exception: 100320
# Started processing call: 100322
# Cautght Exception: 100322
# Started processing call: 100323
# Cautght Exception: 100323
# Started processing call: 100327
# Cautght Exception: 100327
# Started processing call: 100328
# Cautght Exception: 100328
# Started processing call: 100329
# Cautght Exception: 100329
# Started processing call: 100330
# Cautght Exception: 100330
# Started processing call: 100332
# Cautght Exception: 100332
# Started processing call: 100337
# Cautght Exception: 100337
# Started processing call: 100341
# Cautght Exception: 100341
# Started processing call: 100342
# Cautght Exception: 100342
# Started processing call: 100344
# Cautght Exception: 100344
# Started processing call: 100347
# Cautght Exception: 100347
# Started processing call: 100349
# Cautght Exception: 100349
# Started processing call: 100350
# Cautght Exception: 100350
# Started processing call: 100353
# Cautght Exception: 100353
# Started processing call: 100356
# Cautght Exception: 100356
# Started processing call: 100359
# Cautght Exception: 100359
# Started processing call: 100360
# Cautght Exception: 100360
# Started processing call: 100361
# Cautght Exception: 100361
# Started processing call: 100362
# Cautght Exception: 100362
# Started processing call: 100363
# Cautght Exception: 100363
# Started processing call: 100364
# Cautght Exception: 100364
# Started processing call: 100365
# Cautght Exception: 100365
# Started processing call: 100368
# Cautght Exception: 100368
# Started processing call: 100369
# Cautght Exception: 100369
# Started processing call: 100370
# Cautght Exception: 100370
# Started processing call: 100372
# Cautght Exception: 100372
# Started processing call: 100376
# Cautght Exception: 100376
# Started processing call: 100377
# Cautght Exception: 100377
# Started processing call: 100378
# Cautght Exception: 100378
# Started processing call: 100379
# Cautght Exception: 100379
# Started processing call: 10038
# Cautght Exception: 10038
# Started processing call: 100380
# Cautght Exception: 100380
# Started processing call: 100386
# Cautght Exception: 100386
# Started processing call: 100387
# Cautght Exception: 100387
# Started processing call: 100388
# Cautght Exception: 100388
# Started processing call: 100389
# Cautght Exception: 100389
# Started processing call: 10039
# Cautght Exception: 10039
# Started processing call: 100390
# Cautght Exception: 100390
# Started processing call: 100391
# Cautght Exception: 100391
# Started processing call: 100392
# Cautght Exception: 100392
# Started processing call: 100393
# Cautght Exception: 100393
# Started processing call: 100394
# Cautght Exception: 100394
# Started processing call: 100396
# Cautght Exception: 100396
# Started processing call: 100397
# Cautght Exception: 100397
# Started processing call: 100399
# Cautght Exception: 100399
# Started processing call: 1004
# Cautght Exception: 1004
# Started processing call: 10040
# Cautght Exception: 10040
# Started processing call: 100401
# Cautght Exception: 100401
# Started processing call: 100405
# Cautght Exception: 100405
# Started processing call: 100407
# Cautght Exception: 100407
# Started processing call: 100408
# Cautght Exception: 100408
# Started processing call: 100409
# Cautght Exception: 100409
# Started processing call: 10041
# Cautght Exception: 10041
# Started processing call: 100411
# Cautght Exception: 100411
# Started processing call: 100413
# Cautght Exception: 100413
# Started processing call: 100416
# Cautght Exception: 100416
# Started processing call: 100417
# Cautght Exception: 100417
# Started processing call: 100419
# Cautght Exception: 100419
# Started processing call: 100421
# Cautght Exception: 100421
# Started processing call: 100423
# Cautght Exception: 100423
# Started processing call: 100425
# Cautght Exception: 100425
# Started processing call: 100427
# Cautght Exception: 100427
# Started processing call: 100429
# Cautght Exception: 100429
# Started processing call: 100431
# Cautght Exception: 100431
# Started processing call: 100433
# Cautght Exception: 100433
# Started processing call: 100434
# Cautght Exception: 100434
# Started processing call: 100436
# Cautght Exception: 100436
# Started processing call: 100438
# Cautght Exception: 100438
# Started processing call: 100440
# Cautght Exception: 100440
# Started processing call: 100441
# Cautght Exception: 100441
# Started processing call: 100444
# Cautght Exception: 100444
# Started processing call: 100445
# Cautght Exception: 100445
# Started processing call: 100446
# Cautght Exception: 100446
# Started processing call: 100448
# Cautght Exception: 100448
# Started processing call: 100449
# Cautght Exception: 100449
# Started processing call: 10045
# Cautght Exception: 10045
# Started processing call: 100451
# Cautght Exception: 100451
# Started processing call: 100452
# Cautght Exception: 100452
# Started processing call: 100454
# Cautght Exception: 100454
# Started processing call: 100455
# Cautght Exception: 100455
# Started processing call: 100457
# Cautght Exception: 100457
# Started processing call: 100458
# Cautght Exception: 100458
# Started processing call: 100459
# Cautght Exception: 100459
# Started processing call: 10046
# Cautght Exception: 10046
# Started processing call: 100460
# Cautght Exception: 100460
# Started processing call: 100461
# Cautght Exception: 100461
# Started processing call: 100465
# Cautght Exception: 100465
# Started processing call: 100466
# Cautght Exception: 100466
# Started processing call: 100468
# Cautght Exception: 100468
# Started processing call: 100470
# Cautght Exception: 100470
# Started processing call: 100472
# Cautght Exception: 100472
# Started processing call: 100476
# Cautght Exception: 100476
# Started processing call: 100484
# Cautght Exception: 100484
# Started processing call: 100486
# Cautght Exception: 100486
# Started processing call: 100487
# Cautght Exception: 100487
# Started processing call: 100492
# Cautght Exception: 100492
# Started processing call: 100496
# Cautght Exception: 100496
# Started processing call: 100497
# Cautght Exception: 100497
# Started processing call: 1005
# Cautght Exception: 1005
# Started processing call: 10050
# Cautght Exception: 10050
# Started processing call: 100505
# Cautght Exception: 100505
# Started processing call: 100506
# Cautght Exception: 100506
# Started processing call: 100509
# Cautght Exception: 100509
# Started processing call: 10051
# Cautght Exception: 10051
# Started processing call: 100516
# Cautght Exception: 100516
# Started processing call: 100519
# Cautght Exception: 100519
# Started processing call: 10052
# Cautght Exception: 10052
# Started processing call: 100520
# Cautght Exception: 100520
# Started processing call: 100528
# Cautght Exception: 100528
# Started processing call: 10053
# Cautght Exception: 10053
# Started processing call: 100530
# Cautght Exception: 100530
# Started processing call: 100532
# Cautght Exception: 100532
# Started processing call: 100535
# Cautght Exception: 100535
# Started processing call: 100536
# Cautght Exception: 100536
# Started processing call: 100537
# Cautght Exception: 100537
# Started processing call: 100538
# Cautght Exception: 100538
# Started processing call: 100539
# Cautght Exception: 100539
# Started processing call: 100541
# Cautght Exception: 100541
# Started processing call: 100544
# Cautght Exception: 100544
# Started processing call: 100545
# Cautght Exception: 100545
# Started processing call: 100547
# Cautght Exception: 100547
# Started processing call: 100549
# Cautght Exception: 100549
# Started processing call: 100550
# Cautght Exception: 100550
# Started processing call: 100553
# Cautght Exception: 100553
# Started processing call: 100554
# Cautght Exception: 100554
# Started processing call: 100555
# Cautght Exception: 100555
# Started processing call: 100556
# Cautght Exception: 100556
# Started processing call: 100560
# Cautght Exception: 100560
# Started processing call: 100561
# Cautght Exception: 100561
# Started processing call: 100562
# Cautght Exception: 100562
# Started processing call: 100564
# Cautght Exception: 100564
# Started processing call: 100570
# Cautght Exception: 100570
# Started processing call: 100571
# Cautght Exception: 100571
# Started processing call: 100572
# Cautght Exception: 100572
# Started processing call: 100574
# Cautght Exception: 100574
# Started processing call: 100577
# Cautght Exception: 100577
# Started processing call: 100578
# Cautght Exception: 100578
# Started processing call: 100583
# Cautght Exception: 100583
# Started processing call: 100584
# Cautght Exception: 100584
# Started processing call: 100585
# Cautght Exception: 100585
# Started processing call: 100586
# Cautght Exception: 100586
# Started processing call: 10059
# Cautght Exception: 10059
# Started processing call: 100591
# Cautght Exception: 100591
# Started processing call: 100594
# Cautght Exception: 100594
# Started processing call: 100596
# Cautght Exception: 100596
# Started processing call: 10060
# Cautght Exception: 10060
# Started processing call: 100601
# Cautght Exception: 100601
# Started processing call: 100602
# Cautght Exception: 100602
# Started processing call: 100603
# Cautght Exception: 100603
# Started processing call: 100604
# Cautght Exception: 100604
# Started processing call: 100607
# Cautght Exception: 100607
# Started processing call: 100609
# Cautght Exception: 100609
# Started processing call: 100611
# Cautght Exception: 100611
# Started processing call: 100614
# Cautght Exception: 100614
# Started processing call: 100615
# Cautght Exception: 100615
# Started processing call: 100616
# Cautght Exception: 100616
# Started processing call: 100618
# Cautght Exception: 100618
# Started processing call: 100619
# Cautght Exception: 100619
# Started processing call: 100620
# Cautght Exception: 100620
# Started processing call: 100627
# Cautght Exception: 100627
# Started processing call: 10063
# Cautght Exception: 10063
# Started processing call: 100630
# Cautght Exception: 100630
# Started processing call: 100631
# Cautght Exception: 100631
# Started processing call: 100633
# Cautght Exception: 100633
# Started processing call: 100634
# Cautght Exception: 100634
# Started processing call: 100635
# Cautght Exception: 100635
# Started processing call: 100636
# Cautght Exception: 100636
# Started processing call: 100637
# Cautght Exception: 100637
# Started processing call: 100638
# Cautght Exception: 100638
# Started processing call: 100639
# Cautght Exception: 100639
# Started processing call: 10064
# Cautght Exception: 10064
# Started processing call: 100640
# Cautght Exception: 100640
# Started processing call: 100641
# Cautght Exception: 100641
# Started processing call: 100642
# Cautght Exception: 100642
# Started processing call: 100643
# Cautght Exception: 100643
# Started processing call: 100646
# Cautght Exception: 100646
# Started processing call: 100647
# Cautght Exception: 100647
# Started processing call: 100648
# Cautght Exception: 100648
# Started processing call: 100649
# Cautght Exception: 100649
# Started processing call: 100650
# Cautght Exception: 100650
# Started processing call: 100651
# Cautght Exception: 100651
# Started processing call: 100652
# Cautght Exception: 100652
# Started processing call: 100654
# Cautght Exception: 100654
# Started processing call: 100656
# Cautght Exception: 100656
# Started processing call: 100657
# Cautght Exception: 100657
# Started processing call: 100663
# Cautght Exception: 100663
# Started processing call: 100665
# Cautght Exception: 100665
# Started processing call: 100666
# Cautght Exception: 100666
# Started processing call: 100667
# Cautght Exception: 100667
# Started processing call: 100668
# Cautght Exception: 100668
# Started processing call: 100671
# Cautght Exception: 100671
# Started processing call: 100672
# Cautght Exception: 100672
# Started processing call: 100673
# Cautght Exception: 100673
# Started processing call: 100676
# Cautght Exception: 100676
# Started processing call: 100678
# Cautght Exception: 100678
# Started processing call: 100683
# Cautght Exception: 100683
# Started processing call: 100684
# Cautght Exception: 100684
# Started processing call: 100685
# Cautght Exception: 100685
# Started processing call: 100686
# Cautght Exception: 100686
# Started processing call: 100688
# Cautght Exception: 100688
# Started processing call: 10069
# Cautght Exception: 10069
# Started processing call: 100694
# Cautght Exception: 100694
# Started processing call: 100695
# Cautght Exception: 100695
# Started processing call: 100696
# Cautght Exception: 100696
# Started processing call: 100697
# Cautght Exception: 100697
# Started processing call: 100698
# Cautght Exception: 100698
# Started processing call: 100699
# Cautght Exception: 100699
# Started processing call: 100700
# Cautght Exception: 100700
# Started processing call: 100701
# Cautght Exception: 100701
# Started processing call: 100703
# Cautght Exception: 100703
# Started processing call: 100706
# Cautght Exception: 100706
# Started processing call: 100708
# Cautght Exception: 100708
# Started processing call: 100710
# Cautght Exception: 100710
# Started processing call: 100711
# Cautght Exception: 100711
# Started processing call: 100714
# Cautght Exception: 100714
# Started processing call: 100715
# Cautght Exception: 100715
# Started processing call: 100716
# Cautght Exception: 100716
# Started processing call: 10072
# Cautght Exception: 10072
# Started processing call: 100720
# Cautght Exception: 100720
# Started processing call: 100722
# Cautght Exception: 100722
# Started processing call: 100723
# Cautght Exception: 100723
# Started processing call: 100726
# Cautght Exception: 100726
# Started processing call: 100727
# Cautght Exception: 100727
# Started processing call: 100728
# Cautght Exception: 100728
# Started processing call: 100729
# Cautght Exception: 100729
# Started processing call: 10073
# Cautght Exception: 10073
# Started processing call: 100731
# Cautght Exception: 100731
# Started processing call: 100732
# Cautght Exception: 100732
# Started processing call: 100733
# Cautght Exception: 100733
# Started processing call: 100734
# Cautght Exception: 100734
# Started processing call: 100735
# Cautght Exception: 100735
# Started processing call: 100738
# Cautght Exception: 100738
# Started processing call: 100740
# Cautght Exception: 100740
# Started processing call: 100741
# Cautght Exception: 100741
# Started processing call: 100742
# Cautght Exception: 100742
# Started processing call: 100747
# Cautght Exception: 100747
# Started processing call: 100748
# Cautght Exception: 100748
# Started processing call: 100750
# Cautght Exception: 100750
# Started processing call: 100751
# Cautght Exception: 100751
# Started processing call: 100754
# Cautght Exception: 100754
# Started processing call: 100756
# Cautght Exception: 100756
# Started processing call: 100757
# Cautght Exception: 100757
# Started processing call: 100759
# Cautght Exception: 100759
# Started processing call: 100763
# Cautght Exception: 100763
# Started processing call: 100765
# Cautght Exception: 100765
# Started processing call: 100766
# Cautght Exception: 100766
# Started processing call: 100768
# Cautght Exception: 100768
# Started processing call: 10077
# Cautght Exception: 10077
# Started processing call: 100772
# Cautght Exception: 100772
# Started processing call: 100775
# Cautght Exception: 100775
# Started processing call: 100776
# Cautght Exception: 100776
# Started processing call: 100777
# Cautght Exception: 100777
# Started processing call: 100779
# Cautght Exception: 100779
# Started processing call: 10078
# Cautght Exception: 10078
# Started processing call: 100780
# Cautght Exception: 100780
# Started processing call: 100785
# Cautght Exception: 100785
# Started processing call: 100786
# Cautght Exception: 100786
# Started processing call: 100787
# Cautght Exception: 100787
# Started processing call: 100789
# Cautght Exception: 100789
# Started processing call: 100792
# Cautght Exception: 100792
# Started processing call: 100793
# Cautght Exception: 100793
# Started processing call: 100795
# Cautght Exception: 100795
# Started processing call: 1008
# Cautght Exception: 1008
# Started processing call: 100801
# Cautght Exception: 100801
# Started processing call: 100803
# Cautght Exception: 100803
# Started processing call: 10081
# Cautght Exception: 10081
# Started processing call: 100814
# Cautght Exception: 100814
# Started processing call: 100815
# Cautght Exception: 100815
# Started processing call: 100819
# Cautght Exception: 100819
# Started processing call: 100820
# Cautght Exception: 100820
# Started processing call: 100824
# Cautght Exception: 100824
# Started processing call: 100827
# Cautght Exception: 100827
# Started processing call: 100828
# Cautght Exception: 100828
# Started processing call: 100831
# Cautght Exception: 100831
# Started processing call: 100832
# Cautght Exception: 100832
# Started processing call: 100833
# Cautght Exception: 100833
# Started processing call: 100837
# Cautght Exception: 100837
# Started processing call: 100839
# Cautght Exception: 100839
# Started processing call: 10084
# Cautght Exception: 10084
# Started processing call: 100841
# Cautght Exception: 100841
# Started processing call: 100843
# Cautght Exception: 100843
# Started processing call: 100848
# Cautght Exception: 100848
# Started processing call: 10085
# Cautght Exception: 10085
# Started processing call: 100851
# Cautght Exception: 100851
# Started processing call: 100853
# Cautght Exception: 100853
# Started processing call: 100854
# Cautght Exception: 100854
# Started processing call: 100858
# Cautght Exception: 100858
# Started processing call: 100861
# Cautght Exception: 100861
# Started processing call: 100862
# Cautght Exception: 100862
# Started processing call: 100864
# Cautght Exception: 100864
# Started processing call: 100865
# Cautght Exception: 100865
# Started processing call: 100866
# Cautght Exception: 100866
# Started processing call: 100867
# Cautght Exception: 100867
# Started processing call: 10087
# Cautght Exception: 10087
# Started processing call: 100870
# Cautght Exception: 100870
# Started processing call: 100871
# Cautght Exception: 100871
# Started processing call: 100872
# Cautght Exception: 100872
# Started processing call: 100875
# Cautght Exception: 100875
# Started processing call: 100876
# Cautght Exception: 100876
# Started processing call: 100878
# Cautght Exception: 100878
# Started processing call: 10088
# Cautght Exception: 10088
# Started processing call: 100885
# Cautght Exception: 100885
# Started processing call: 100886
# Cautght Exception: 100886
# Started processing call: 100891
# Cautght Exception: 100891
# Started processing call: 100895
# Cautght Exception: 100895
# Started processing call: 100898
# Cautght Exception: 100898
# Started processing call: 100899
# Cautght Exception: 100899
# Started processing call: 100900
# Cautght Exception: 100900
# Started processing call: 100903
# Cautght Exception: 100903
# Started processing call: 100906
# Cautght Exception: 100906
# Started processing call: 100908
# Cautght Exception: 100908
# Started processing call: 10091
# Cautght Exception: 10091
# Started processing call: 100910
# Cautght Exception: 100910
# Started processing call: 100918
# Cautght Exception: 100918
# Started processing call: 100919
# Cautght Exception: 100919
# Started processing call: 100921
# Cautght Exception: 100921
# Started processing call: 100923
# Cautght Exception: 100923
# Started processing call: 100927
# Cautght Exception: 100927
# Started processing call: 100929
# Cautght Exception: 100929
# Started processing call: 100935
# Cautght Exception: 100935
# Started processing call: 100936
# Cautght Exception: 100936
# Started processing call: 10094
# Cautght Exception: 10094
# Started processing call: 100942
# Cautght Exception: 100942
# Started processing call: 100945
# Cautght Exception: 100945
# Started processing call: 100946
# Cautght Exception: 100946
# Started processing call: 100950
# Cautght Exception: 100950
# Started processing call: 100954
# Cautght Exception: 100954
# Started processing call: 100956
# Cautght Exception: 100956
# Started processing call: 100957
# Cautght Exception: 100957
# Started processing call: 100958
# Cautght Exception: 100958
# Started processing call: 100959
# Cautght Exception: 100959
# Started processing call: 100963
# Cautght Exception: 100963
# Started processing call: 100965
# Cautght Exception: 100965
# Started processing call: 100966
# Cautght Exception: 100966
# Started processing call: 100967
# Cautght Exception: 100967
# Started processing call: 100975
# Cautght Exception: 100975
# Started processing call: 100978
# Cautght Exception: 100978
# Started processing call: 10098
# Cautght Exception: 10098
# Started processing call: 100981
# Cautght Exception: 100981
# Started processing call: 100985
# Cautght Exception: 100985
# Started processing call: 100986
# Cautght Exception: 100986
# Started processing call: 100999
# Cautght Exception: 100999
# Started processing call: 101000
# Cautght Exception: 101000
# Started processing call: 101001
# Cautght Exception: 101001
# Started processing call: 101005
# Cautght Exception: 101005
# Started processing call: 10101
# Cautght Exception: 10101
# Started processing call: 101016
# Cautght Exception: 101016
# Started processing call: 101017
# Cautght Exception: 101017
# Started processing call: 101018
# Cautght Exception: 101018
# Started processing call: 101019
# Cautght Exception: 101019
# Started processing call: 101021
# Cautght Exception: 101021
# Started processing call: 101022
# Cautght Exception: 101022
# Started processing call: 101026
# Cautght Exception: 101026
# Started processing call: 101027
# Cautght Exception: 101027
# Started processing call: 101028
# Cautght Exception: 101028
# Started processing call: 101032
# Cautght Exception: 101032
# Started processing call: 101033
# Cautght Exception: 101033
# Started processing call: 101035
# Cautght Exception: 101035
# Started processing call: 101037
# Cautght Exception: 101037
# Started processing call: 101038
# Cautght Exception: 101038
# Started processing call: 10104
# Cautght Exception: 10104
# Started processing call: 101041
# Cautght Exception: 101041
# Started processing call: 101042
# Cautght Exception: 101042
# Started processing call: 101045
# Cautght Exception: 101045
# Started processing call: 101047
# Cautght Exception: 101047
# Started processing call: 101049
# Cautght Exception: 101049
# Started processing call: 101051
# Cautght Exception: 101051
# Started processing call: 101053
# Cautght Exception: 101053
# Started processing call: 101054
# Cautght Exception: 101054
# Started processing call: 101055
# Cautght Exception: 101055
# Started processing call: 125131
# Cautght Exception: 125131
# Started processing call: 125135
# Cautght Exception: 125135
# Started processing call: 125138
# Cautght Exception: 125138
# Started processing call: 12514
# Cautght Exception: 12514
# Started processing call: 125142
# Cautght Exception: 125142
# Started processing call: 125144
# Cautght Exception: 125144
# Started processing call: 125147
# Cautght Exception: 125147
# Started processing call: 125149
# Cautght Exception: 125149
# Started processing call: 12515
# Cautght Exception: 12515
# Started processing call: 125150
# Cautght Exception: 125150
# Started processing call: 125154
# Cautght Exception: 125154
# Started processing call: 125155
# Cautght Exception: 125155
# Started processing call: 125156
# Cautght Exception: 125156
# Started processing call: 125158
# Cautght Exception: 125158
# Started processing call: 125163
# Cautght Exception: 125163
# Started processing call: 125167
# Cautght Exception: 125167
# Started processing call: 125168
# Cautght Exception: 125168
# Started processing call: 125169
# Cautght Exception: 125169
# Started processing call: 125171
# Cautght Exception: 125171
# Started processing call: 125173
# Cautght Exception: 125173
# Started processing call: 125176
# Cautght Exception: 125176
# Started processing call: 125177
# Cautght Exception: 125177
# Started processing call: 125178
# Cautght Exception: 125178
# Started processing call: 125180
# Cautght Exception: 125180
# Started processing call: 125183
# Cautght Exception: 125183
# Started processing call: 125185
# Cautght Exception: 125185
# Started processing call: 125186
# Cautght Exception: 125186
# Started processing call: 125187
# Cautght Exception: 125187
# Started processing call: 125188
# Cautght Exception: 125188
# Started processing call: 12519
# Cautght Exception: 12519
# Started processing call: 125190
# Cautght Exception: 125190
# Started processing call: 125191
# Cautght Exception: 125191
# Started processing call: 125192
# Cautght Exception: 125192
# Started processing call: 125193
# Cautght Exception: 125193
# Started processing call: 125194
# Cautght Exception: 125194
# Started processing call: 125197
# Cautght Exception: 125197
# Started processing call: 1252
# Cautght Exception: 1252
# Started processing call: 12520
# Cautght Exception: 12520
# Started processing call: 125200
# Cautght Exception: 125200
# Started processing call: 125203
# Cautght Exception: 125203
# Started processing call: 125204
# Cautght Exception: 125204
# Started processing call: 125210
# Cautght Exception: 125210
# Started processing call: 125214
# Cautght Exception: 125214
# Started processing call: 125215
# Cautght Exception: 125215
# Started processing call: 125218
# Cautght Exception: 125218
# Started processing call: 125219
# Cautght Exception: 125219
# Started processing call: 12522
# Cautght Exception: 12522
# Started processing call: 125220
# Cautght Exception: 125220
# Started processing call: 125221
# Cautght Exception: 125221
# Started processing call: 125224
# Cautght Exception: 125224
# Started processing call: 125226
# Cautght Exception: 125226
# Started processing call: 125227
# Cautght Exception: 125227

# %% [markdown]
# # 6. Inter Calls KPIs

# %%
df_inter_calls_data = pd.read_csv("df_inter_calls_data.csv")
df_inter_calls_data.call_id = df_inter_calls_data.call_id.astype('str')
# df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)

# %%
df_inter_calls_data.shape
# Out:
# (72, 9)

# %%
df_inter_calls_data.call_id.unique()
# Out:
# array(['279902', '2807561', '281491', '150827', '131703', '165108',
#        '184817', '1000', '1', '10000', '100002', '100003', '100004',
#        '100007', '100009', '10001', '100011', '100012', '100013',
#        '100014', '100017', '100018', '100019', '100024', '100025',
#        '100026', '100028', '100029', '10003', '100030', '100031',
#        '100032', '100033', '100034', '100035', '100036', '100037',
#        '100039', '10004', '100040', '100041', '100042', '100043',
#        '100044', '100045', '100046', '100047', '100048', '100049',
#        '10005', '100050', '100051', '100052', '100053', '100054',
#        '100055', '100056', '100057', '100058', '100059', '10006',
#        '100060', '100062', '100063', '100064', '100065', '100068',
#        '100069', '10007', '100070', '100072', '100073'], dtype=object)

# %% [markdown]
# ## 6.1 Inter Call Summary

# %%
prompt_summary = "Given a call transcription, suggest an informative and concise summary of not more than 100 words."

# %%
def get_call_summary(call_text):
    task = "generate summary."
    summary_list = generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt_summary, call_text)
    summary = " ".join(summary_list[1:]).replace("Call Summary:","").replace("\n","").strip()
    # print(summary)
    return summary

# %%
current_index = 0
call_summary_list = []

# %%
len(call_summary_list)
# Out:
# 72

# %%
current_index
# Out:
# 0

# %%
while current_index < df_inter_calls_data.shape[0]:
    print(current_index)
    try:
        call_summary_list.append(get_call_summary(df_inter_calls_data.call_text[current_index]))
        current_index += 1
        
    except Exception as e:
        print("Excepted at: "+str(current_index))
        print("Sleeping for seconds: "+str(30))
        time.sleep(30)
# Out:
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# Excepted at: 12
# Sleeping for seconds: 30
# 12
# Excepted at: 12
# Sleeping for seconds: 30
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# Excepted at: 18
# Sleeping for seconds: 30
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# Excepted at: 24
# Sleeping for seconds: 30
# 24
# Excepted at: 24
# Sleeping for seconds: 30
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# Excepted at: 30
# Sleeping for seconds: 30
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# Excepted at: 36
# Sleeping for seconds: 30
# 36
# Excepted at: 36
# Sleeping for seconds: 30
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# Excepted at: 42
# Sleeping for seconds: 30
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# Excepted at: 48
# Sleeping for seconds: 30
# 48
# Excepted at: 48
# Sleeping for seconds: 30
# 48
# 49
# 50
# 51
# 52
# 53
# 54
# Excepted at: 54
# Sleeping for seconds: 30
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# Excepted at: 60
# Sleeping for seconds: 30
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# Excepted at: 66
# Sleeping for seconds: 30
# 66
# Excepted at: 66
# Sleeping for seconds: 30
# 66
# 67
# 68
# 69
# 70
# 71

# %%
df_inter_calls_data.call_summary=call_summary_list

# %% [markdown]
# ### Append

# %%
df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
df_inter_calls_data
# Out:
#     call_id                                          call_text  \
# 0    279902  Hello. Yes Yeah. All right Yes Okay. Were you ...
# 1   2807561  Thanks for calling TTech support. My name is L...
# 2    281491  Thanks for calling TTech support. My name is L...
# 3    150827  Thank you for calling Atom services. My name i...
# 4    131703  silence call sound escalated virtual agent cal...
# ..      ...                                                ...
# 67   100069  caption Thank you for calling TTech and at hom...
# 68    10007  caption** Thank you for calling TTEC at home s...
# 69   100070  Hello? Thank you for calling Amazon support Hi...
# 70   100072  Thank you for calling Adams office first. My n...
# 71   100073  end  and timestamps.  or specific names if kno...
#
#                                          call_summary  \
# 0   The user is experiencing persistent errors whi...
# 1   Louie, working from home in production for Blu...
# 2   Louis from Covered California contacted TTech ...
# 3   Two-Way Audio Issue**Mr. Maha** contacted Atom...
# 4   **Stanley Riles, an employee of Independence B...
# ..                                                ...
# 67  Tiffany Ellis, a TTech employee working for Da...
# 68  TTEC Agent Onboarding AssistanceThis call invo...
# 69  Thea Villean Ash Davis, Oracle ID 22 71270, fr...
# 70  Senia Arroyo called on her first day of traini...
# 71  **Inbound call from Alecia at At Home Service ...
#
#                                                 topic  \
# 0                Troubleshooting  Windows login error
# 1                          New  computer login issues
# 2                         Global  Protect login issue
# 3      Troubleshooting  two-way audio issues on Zoom.
# 4   Troubleshooting  SRW login issues for Stanley ...
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
#
#                          category                   sub_category  \
# 0   Technical SupportSub-category                   Login Issues
# 1   Technical SupportSub-Category                   Login Issues
# 2          IT SupportSub-Category        Remote Access/VPN Issue
# 3   Technical SupportSub-Category             Audio/Video Issues
# 4                        Category  Technical SupportSub-category
# ..                            ...                            ...
# 67                            NaN                            NaN
# 68                            NaN                            NaN
# 69                            NaN                            NaN
# 70                            NaN                            NaN
# 71                            NaN                            NaN
#
#                               overall_user_sentiments  \
# 0      Frustrated, confused, and eventually resigned.
# 1   Initially frustrated, then relieved and grateful.
# 2   Initially neutral, becomes slightly frustrated...
# 3              Confused, then cooperative and polite.
# 4                     Frustrated, impatient, stressed
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
#
#                 overall_agent_sentiments  \
# 0   Patient, repetitive, and methodical.
# 1    Patient, helpful, and professional.
# 2              Neutral and professional.
# 3    Helpful, patient, and professional.
# 4            Calm, helpful, professional
# ..                                   ...
# 67                                   NaN
# 68                                   NaN
# 69                                   NaN
# 70                                   NaN
# 71                                   NaN
#
#                                        agent_coaching
# 0   1. Active Listening: Minimize interruptions li...
# 1   1. Reduce Verification Questions: Streamline t...
# 2   1. Active Listening:  Avoid interrupting Maria...
# 3   1. Active Listening: Avoid interrupting and us...
# 4   1. Active Listening:  Avoid interrupting the c...
# ..                                                ...
# 67                                                NaN
# 68                                                NaN
# 69                                                NaN
# 70                                                NaN
# 71                                                NaN
#
# [72 rows x 9 columns]

# %% [markdown]
# ## 6.2 Inter Call Topic

# %%
prompt_topic = "Given a call transcription, provide one informative topic in 10 words."

# %%
current_index = 0
max_retries = 3
call_topic_list = []

# %%
def get_call_topic(call_text):
    task = "generate topic."
    topic_list = generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt_topic, call_text)
    topic = " ".join(topic_list).replace("\n","").strip()
    return topic

# %%
while current_index < df_inter_calls_data.shape[0]:
    retries = 0
    while retries < max_retries:
        print(current_index)
        try:
            call_topic_list.append(get_call_topic(df_inter_calls_data.call_text[current_index]))
            current_index += 1

        except Exception as e:
            retries += 1
            print("Excepted at: "+str(current_index))
            print("Sleeping for seconds: "+str(30))
            time.sleep(30)
        
        finally:
            if retries == max_retries:
                current_index += 1
                print("Max Tries done. Append empty value.")
                call_topic_list.append("")
# Out:
# 61
# 62
# 63
# 64
# 65
# Excepted at: 65
# Sleeping for seconds: 30
# 65
# Excepted at: 65
# Sleeping for seconds: 30
# 65
# Excepted at: 65
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# Excepted at: 72
# Sleeping for seconds: 30
# 72
# Excepted at: 72
# Sleeping for seconds: 30
# 72
# Excepted at: 72
# Sleeping for seconds: 30
# Max Tries done. Append empty value.

# %%
df_inter_calls_data.topic = call_topic_list

# %% [markdown]
# ### Append

# %%
df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
df_inter_calls_data.head(10)
# Out:
#    call_id                                          call_text  \
# 0   279902  Hello. Yes Yeah. All right Yes Okay. Were you ...
# 1  2807561  Thanks for calling TTech support. My name is L...
# 2   281491  Thanks for calling TTech support. My name is L...
# 3   150827  Thank you for calling Atom services. My name i...
# 4   131703  silence call sound escalated virtual agent cal...
# 5   165108  caption**  (Upbeat music playing)  Thank you f...
# 6   184817  caption Thank you for calling Atom service des...
# 7     1000  Sound of car driving Sound of car stopping Sil...
# 8        1  Sounds of traffic and car horns Sound of a car...
# 9    10000  silence Thank you for calling At Home Service ...
#
#                                         call_summary  \
# 0  The user is experiencing persistent errors whi...
# 1  Louie, working from home in production for Blu...
# 2  Louis from Covered California contacted TTech ...
# 3  Two-Way Audio Issue**Mr. Maha** contacted Atom...
# 4  **Stanley Riles, an employee of Independence B...
# 5  The caller is experiencing issues with Citrix ...
# 6  **Diane**, a Peloton employee, contacted the A...
# 7  The call begins with background noise suggesti...
# 8  The call begins with background noise suggesti...
# 9  Haley Creekmore, a new Ttec employee on her fi...
#
#                                                topic  \
# 0               Troubleshooting  Windows login error
# 1                          New  computer login issue
# 2                        Global  Protect login issue
# 3     Troubleshooting  two-way audio issues on Zoom.
# 4  Troubleshooting  SRW login issues for Stanley ...
# 5   ** Citrix freezing issue impacting user access**
# 6    Troubleshooting  SRW application launch failure
# 7                            Arrival  at destination
# 8                Traffic  noise during a phone call.
# 9       Agent  assists employee with computer setup.
#
#                         category                      sub_category  \
# 0  Technical SupportSub-category                      Login Issues
# 1  Technical SupportSub-Category                      Login Issues
# 2         IT SupportSub-Category           Remote Access/VPN Issue
# 3  Technical SupportSub-Category                Audio/Video Issues
# 4                       Category     Technical SupportSub-category
# 5      Citrix Issue Sub-Category              Freezing/Performance
# 6  Technical SupportSub-Category  Software Issue (SRW Application)
# 7                            NaN                               NaN
# 8                            NaN                               NaN
# 9                            NaN                               NaN
#
#                              overall_user_sentiments  \
# 0     Frustrated, confused, and eventually resigned.
# 1  Initially frustrated, then relieved and grateful.
# 2  Initially neutral, becomes slightly frustrated...
# 3             Confused, then cooperative and polite.
# 4                    Frustrated, impatient, stressed
# 5                              Neutral, professional
# 6                    Professional, helpful, patient.
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                  overall_agent_sentiments  \
# 0    Patient, repetitive, and methodical.
# 1     Patient, helpful, and professional.
# 2               Neutral and professional.
# 3     Helpful, patient, and professional.
# 4             Calm, helpful, professional
# 5                    Frustrated, confused
# 6  Frustrated, confused, but cooperative.
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                       agent_coaching
# 0  1. Active Listening: Minimize interruptions li...
# 1  1. Reduce Verification Questions: Streamline t...
# 2  1. Active Listening:  Avoid interrupting Maria...
# 3  1. Active Listening: Avoid interrupting and us...
# 4  1. Active Listening:  Avoid interrupting the c...
# 5  1. Active Listening:  Suma should avoid interr...
# 6  1. Active Listening:  Suma should focus on act...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# ## 6.3 Call Category

# %%
prmopt_category = "Given a call transcription, provide one category and one sub-category."

# %%
current_index = 0
max_retries = 2
categorys, subCategorys = [], []

# %%
def get_category_subCategory(call_text):
    task = "generate Category and Sub-Category."
    category_list = generate_resp_from_transcript(model, generation_config, safety_settings, task, prmopt_category, call_text)
    category_subCategory = "".join(category_list).replace("*","").replace("\n","").split(":")[1:]
    category = category_subCategory[0].strip()
    subCategory = category_subCategory[1].strip()
    return category, subCategory

# %%
while current_index < df_inter_calls_data.shape[0]:
    retries = 0
    while retries < max_retries:
        print(current_index)
        try:
            category, subCategory = get_category_subCategory(df_inter_calls_data.call_text[current_index])
            categorys.append(category)
            subCategorys.append(subCategory)
            current_index += 1

        except Exception as e:
            retries += 1
            print("Excepted at: "+str(current_index))
            print("Sleeping for seconds: "+str(30))
            time.sleep(30)
        
        finally:
            if retries == max_retries:
                current_index += 1
                print("Max Tries done. Append empty value.")
                categorys.append("")
                subCategorys.append("")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# Excepted at: 6
# Sleeping for seconds: 30
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# Excepted at: 12
# Sleeping for seconds: 30
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# Excepted at: 18
# Sleeping for seconds: 30
# 18
# Excepted at: 18
# Sleeping for seconds: 30
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# Excepted at: 24
# Sleeping for seconds: 30
# 24
# Excepted at: 24
# Sleeping for seconds: 30
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# Excepted at: 30
# Sleeping for seconds: 30
# 30
# Excepted at: 30
# Sleeping for seconds: 30
# 30
# 31
# 32
# 33
# 34
# 35
# 36
# Excepted at: 36
# Sleeping for seconds: 30
# 36
# 37
# 38
# 39
# 40
# 41
# 42
# Excepted at: 42
# Sleeping for seconds: 30
# 42
# Excepted at: 42
# Sleeping for seconds: 30
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# Excepted at: 48
# Sleeping for seconds: 30
# 48
# Excepted at: 48
# Sleeping for seconds: 30
# 48
# 49
# 50
# 51
# 52
# 53
# 54
# Excepted at: 54
# Sleeping for seconds: 30
# 54
# Excepted at: 54
# Sleeping for seconds: 30
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# Excepted at: 60
# Sleeping for seconds: 30
# 60
# 61
# 62
# 63
# 64
# 65
# 66
# Excepted at: 66
# Sleeping for seconds: 30
# 66
# Excepted at: 66
# Sleeping for seconds: 30
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# Excepted at: 72
# Sleeping for seconds: 30
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/pandas/core/indexes/range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 72 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[128], line 6
#       5 try:
# ----> 6     category, subCategory = get_category_subCategory(df_inter_calls_data.call_text[current_index])
#       7     categorys.append(category)
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#
# File /opt/conda/envs/gemini/lib/python3.10/site-packages/pandas/core/indexes/range.py:415, in RangeIndex.get_loc(self, key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#
# KeyError: 72
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[128], line 14
#      12     print("Excepted at: "+str(current_index))
#      13     print("Sleeping for seconds: "+str(30))
# ---> 14     time.sleep(30)
#      16 finally:
#      17     if retries == max_retries:
#
# KeyboardInterrupt:

# %%
df_inter_calls_data['category'] = categorys
df_inter_calls_data['sub_category'] = subCategorys

# %% [markdown]
# ### Append

# %%
df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
df_inter_calls_data.head(10)
# Out:
#    call_id                                          call_text  \
# 0   279902  Hello. Yes Yeah. All right Yes Okay. Were you ...
# 1  2807561  Thanks for calling TTech support. My name is L...
# 2   281491  Thanks for calling TTech support. My name is L...
# 3   150827  Thank you for calling Atom services. My name i...
# 4   131703  silence call sound escalated virtual agent cal...
# 5   165108  caption**  (Upbeat music playing)  Thank you f...
# 6   184817  caption Thank you for calling Atom service des...
# 7     1000  Sound of car driving Sound of car stopping Sil...
# 8        1  Sounds of traffic and car horns Sound of a car...
# 9    10000  silence Thank you for calling At Home Service ...
#
#                                         call_summary  \
# 0  The user is experiencing persistent errors whi...
# 1  Louie, working from home in production for Blu...
# 2  Louis from Covered California contacted TTech ...
# 3  Two-Way Audio Issue**Mr. Maha** contacted Atom...
# 4  **Stanley Riles, an employee of Independence B...
# 5  The caller is experiencing issues with Citrix ...
# 6  **Diane**, a Peloton employee, contacted the A...
# 7  The call begins with background noise suggesti...
# 8  The call begins with background noise suggesti...
# 9  Haley Creekmore, a new Ttec employee on her fi...
#
#                                                topic  \
# 0               Troubleshooting  Windows login error
# 1                          New  computer login issue
# 2                        Global  Protect login issue
# 3     Troubleshooting  two-way audio issues on Zoom.
# 4  Troubleshooting  SRW login issues for Stanley ...
# 5   ** Citrix freezing issue impacting user access**
# 6    Troubleshooting  SRW application launch failure
# 7                            Arrival  at destination
# 8                Traffic  noise during a phone call.
# 9       Agent  assists employee with computer setup.
#
#                         category                        sub_category  \
# 0  Technical SupportSub-category                        Login Issues
# 1  Technical SupportSub-Category                        Login Issues
# 2         IT SupportSub-Category             Remote Access/VPN Issue
# 3  Technical SupportSub-Category                  Audio/Video Issues
# 4                       Category       Technical SupportSub-Category
# 5       Citrix IssueSub-Category                Freezing/Performance
# 6                       Category     Technical Support  Sub-Category
# 7                       Category  Environmental Sounds  Sub-Category
# 8                       Category  Environmental Sounds  Sub-Category
# 9         IT SupportSub-Category           Account Setup/Login Issue
#
#                              overall_user_sentiments  \
# 0     Frustrated, confused, and eventually resigned.
# 1  Initially frustrated, then relieved and grateful.
# 2  Initially neutral, becomes slightly frustrated...
# 3             Confused, then cooperative and polite.
# 4                    Frustrated, impatient, stressed
# 5                              Neutral, professional
# 6                    Professional, helpful, patient.
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                  overall_agent_sentiments  \
# 0    Patient, repetitive, and methodical.
# 1     Patient, helpful, and professional.
# 2               Neutral and professional.
# 3     Helpful, patient, and professional.
# 4             Calm, helpful, professional
# 5                    Frustrated, confused
# 6  Frustrated, confused, but cooperative.
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                       agent_coaching
# 0  1. Active Listening: Minimize interruptions li...
# 1  1. Reduce Verification Questions: Streamline t...
# 2  1. Active Listening:  Avoid interrupting Maria...
# 3  1. Active Listening: Avoid interrupting and us...
# 4  1. Active Listening:  Avoid interrupting the c...
# 5  1. Active Listening:  Suma should avoid interr...
# 6  1. Active Listening:  Suma should focus on act...
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %% [markdown]
# ## 6.3 Inter Call Overall Speaker Sentiment

# %%
prompt_overall_sentiment_speaker = "Given a call transcription provide overall sentiment for each speaker in few words."

# %%
current_index = 0
max_retries = 2
overall_user_sentiments, overall_customer_sentiments = [], []

# %%
def get_overall_speakers_sentiment(call_text):
    task = "generate overall speakers sentiments."
    snetiment_list = generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt_overall_sentiment_speaker, call_text)
    overall_sentiments = "".join(snetiment_list).replace("*","").split("\n")[2:-1]
    overall_user_sentiment = overall_sentiments[0].split(":")[1].strip()
    overall_customer_sentiment = overall_sentiments[1].split(":")[1].strip()
    return overall_user_sentiment, overall_customer_sentiment

# %%
len(overall_user_sentiments)
# Out:
# 20

# %%
while current_index < df_inter_calls_data.shape[0]:
    retries = 0
    while retries < max_retries:
        print(current_index)
        try:
            overall_user_sentiment, overall_customer_sentiment = get_overall_speakers_sentiment(df_inter_calls_data.call_text[current_index])
            overall_user_sentiments.append(overall_user_sentiment)
            overall_customer_sentiments.append(overall_customer_sentiment)
            current_index += 1

        except Exception as e:
            retries += 1
            print("Excepted at: "+str(current_index))
            print("Sleeping for seconds: "+str(30))
            time.sleep(30)
        
        finally:
            if retries == max_retries:
                current_index += 1
                print("Max Tries done. Append empty value.")
                overall_user_sentiments.append("")
                overall_customer_sentiments.append("")
# Out:
# 21
# Excepted at: 21
# Sleeping for seconds: 30
# 21
# Excepted at: 21
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 22
# Excepted at: 22
# Sleeping for seconds: 30
# 22
# Excepted at: 22
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# Excepted at: 29
# Sleeping for seconds: 30
# 29
# 30
# 31
# 32
# 33
# 34
# 35
# Excepted at: 35
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 36
# Excepted at: 36
# Sleeping for seconds: 30
# 36
# Excepted at: 36
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 37
# 38
# Excepted at: 38
# Sleeping for seconds: 30
# 38
# Excepted at: 38
# Sleeping for seconds: 30
# Max Tries done. Append empty value.
# 39
# 40
# 41
# 42
# Excepted at: 42
# Sleeping for seconds: 30

# %%
df_inter_calls_data['overall_user_sentiments'] = overall_user_sentiments
df_inter_calls_data['overall_agent_sentiments'] = overall_customer_sentiments

# %% [markdown]
# ### Append

# %%
df_inter_calls_data = df_inter_calls_data.rename(columns = {'overall_customer_sentiments': 'overall_agent_sentiments'})

# %%
df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
df_inter_calls_data.head(10)
# Out:
#    call_id                                          call_text  \
# 0   279902  Hello. Yes Yeah. All right Yes Okay. Were you ...
# 1  2807561  Thanks for calling TTech support. My name is L...
# 2   281491  Thanks for calling TTech support. My name is L...
# 3   150827  Thank you for calling Atom services. My name i...
# 4   131703  silence call sound escalated virtual agent cal...
# 5   165108  caption**  (Upbeat music playing)  Thank you f...
# 6   184817  caption Thank you for calling Atom service des...
#
#                                         call_summary  \
# 0  The user is experiencing persistent internet c...
# 1  Louie, working from home in production for Blu...
# 2  Louis from Covered California contacted TTech ...
# 3  Two-Way Audio Issue**Mr. Maha** contacted Atom...
# 4  **Stanley Riles, an employee of Independence B...
# 5  The caller is experiencing issues with Citrix ...
# 6  **Diane from the Peloton project is experienci...
#
#                                                topic  \
# 0               Troubleshooting  Windows login error
# 1                         New  computer login issues
# 2                        Global  Protect login issue
# 3     Troubleshooting  two-way audio issues on Zoom.
# 4  Troubleshooting  SRW login issues for Stanley ...
# 5              Citrix freezing issue since 11:50 EST
# 6
#
#                         category                   sub_category  \
# 0                       Category  Technical SupportSub-category
# 1  Technical SupportSub-Category                   Login Issues
# 2         IT SupportSub-Category        Remote Access/VPN Issue
# 3  Technical SupportSub-Category             Audio/Video Issues
# 4                       Category  Technical SupportSub-Category
# 5       Citrix IssueSub-Category           Freezing/Performance
# 6
#
#                              overall_user_sentiments  \
# 0     Frustrated, confused, and eventually resigned.
# 1  Initially frustrated, then relieved and grateful.
# 2  Initially neutral, becomes slightly frustrated...
# 3             Confused, then cooperative and polite.
# 4                    Frustrated, impatient, stressed
# 5                              Neutral, professional
# 6                    Professional, helpful, patient.
#
#                  overall_agent_sentiments               agent_coaching
# 0    Patient, repetitive, and methodical.  Active Listening & Empathy:
# 1     Patient, helpful, and professional.        Areas of Improvement:
# 2               Neutral and professional.   Greeting and Introduction:
# 3     Helpful, patient, and professional.       Areas for Improvement:
# 4             Calm, helpful, professional                          NaN
# 5                    Frustrated, confused                          NaN
# 6  Frustrated, confused, but cooperative.                          NaN

# %% [markdown]
# ## 6.4 Agent Coaching

# %%
prompt_coaching = "Given a call transcription provide top 5 coaching tips for Agent to better Customer Experience in less than 100 words."

# %% [markdown]
# ### Loop

# %%
coaching_list = []
for call_text in df_inter_calls_data.call_text:
    task = "generate Agent Coaching."
    coaching_resp = generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt_coaching, call_text)
    coaching = "\n".join("".join(coaching_resp).replace("*","").split("\n")[2:-1])
    coaching_list.append(coaching)

# %%
coaching_list

# %% [markdown]
# ### Manual

# %%
len(coaching_list)
# Out:
# 7

# %%
# call_text = df_inter_calls_data.call_text[6]
# task = "generate Agent Coaching."
# coaching_resp = generate_resp_from_transcript(model, generation_config, safety_settings, task, prompt_coaching, call_text)
# coaching = "\n".join("".join(coaching_resp).replace("*","").split("\n")[2:-1])
# coaching_list.append(coaching)
# Out:
# INFO:root:Started: generate Agent Coaching.
# INFO:root:['##', ' Coaching Tips for Suma:\n\n1. **Active Listening:**  Suma should focus', " on actively listening to the customer's issue instead of interrupting with questions. ", '\n2. **Empathy:**  Show empathy and understanding towards the customer\'s frustration. Phrases like "I understand this is frustrating" can go a long', ' way.\n3. **Clear Communication:**  Suma should avoid technical jargon and use simple, clear language to explain steps and solutions.\n4. **Confirmation', ':**  Regularly confirm understanding by summarizing the issue and proposed solutions.\n5. **Patience:**  Be patient with the customer, especially when guiding them through technical steps. \n']
# INFO:root:Completed: generate Agent Coaching.

# %% [markdown]
# ### Append

# %%
df_inter_calls_data['agent_coaching'] = coaching_list
df_inter_calls_data.to_csv("df_inter_calls_data.csv", index=False)
df_inter_calls_data.head(10)
# Out:
#    call_id                                          call_text  \
# 0   279902  Hello. Yes Yeah. All right Yes Okay. Were you ...
# 1  2807561  Thanks for calling TTech support. My name is L...
# 2   281491  Thanks for calling TTech support. My name is L...
# 3   150827  Thank you for calling Atom services. My name i...
# 4   131703  silence call sound escalated virtual agent cal...
# 5   165108  caption**  (Upbeat music playing)  Thank you f...
# 6   184817  caption Thank you for calling Atom service des...
#
#                                         call_summary  \
# 0  The user is experiencing persistent internet c...
# 1  Louie, working from home in production for Blu...
# 2  Louis from Covered California contacted TTech ...
# 3  Two-Way Audio Issue**Mr. Maha** contacted Atom...
# 4  **Stanley Riles, an employee of Independence B...
# 5  The caller is experiencing issues with Citrix ...
# 6  **Diane from the Peloton project is experienci...
#
#                                                topic  \
# 0               Troubleshooting  Windows login error
# 1                         New  computer login issues
# 2                        Global  Protect login issue
# 3     Troubleshooting  two-way audio issues on Zoom.
# 4  Troubleshooting  SRW login issues for Stanley ...
# 5              Citrix freezing issue since 11:50 EST
# 6    Troubleshooting  SRW application launch failure
#
#                         category                      sub_category  \
# 0  Technical SupportSub-category                      Login Issues
# 1  Technical SupportSub-Category                      Login Issues
# 2         IT SupportSub-Category           Remote Access/VPN Issue
# 3  Technical SupportSub-Category                Audio/Video Issues
# 4                       Category     Technical SupportSub-category
# 5      Citrix Issue Sub-Category              Freezing/Performance
# 6  Technical SupportSub-Category  Software Issue (SRW Application)
#
#                              overall_user_sentiments  \
# 0     Frustrated, confused, and eventually resigned.
# 1  Initially frustrated, then relieved and grateful.
# 2  Initially neutral, becomes slightly frustrated...
# 3             Confused, then cooperative and polite.
# 4                    Frustrated, impatient, stressed
# 5                              Neutral, professional
# 6                    Professional, helpful, patient.
#
#                  overall_agent_sentiments  \
# 0    Patient, repetitive, and methodical.
# 1     Patient, helpful, and professional.
# 2               Neutral and professional.
# 3     Helpful, patient, and professional.
# 4             Calm, helpful, professional
# 5                    Frustrated, confused
# 6  Frustrated, confused, but cooperative.
#
#                                       agent_coaching
# 0  1. Active Listening: Minimize interruptions li...
# 1  1. Reduce Verification Questions: Streamline t...
# 2  1. Active Listening:  Avoid interrupting Maria...
# 3  1. Active Listening: Avoid interrupting and us...
# 4  1. Active Listening:  Avoid interrupting the c...
# 5  1. Active Listening:  Suma should avoid interr...
# 6  1. Active Listening:  Suma should focus on act...

# %% [markdown]
# # 7 Intra Calls KPIs

# %%
df_intra_calls_data = pd.read_csv("df_intra_calls_data.csv")
df_intra_calls_data.call_id = df_intra_calls_data.call_id.astype('str')

# %%
df_intra_calls_data.call_id.unique().tolist()
# Out:
# ['279902', '2807561', '281491', '150827', '131703', '165108', '184817']

# %%
df_intra_calls_data.head()
# Out:
#   call_id  start    end speaker            text  negative  neutral  positive  \
# 0  279902  00:01  00:05  Ramelo             Yes      8.97    45.49     45.53
# 1  279902  00:09  00:11     Joy           Yeah.      9.89    57.98     32.13
# 2  279902  00:11  00:16  Ramelo       All right      7.15    52.12     40.73
# 3  279902  00:22  00:29     Joy             Yes      8.97    45.49     45.53
# 4  279902  00:29  00:32  Ramelo  Okay. Were you      3.45    86.24     10.31
#
#   SentimentLable  SentimentScore  \
# 0       POSITIVE        0.999781
# 1       POSITIVE        0.999524
# 2       POSITIVE        0.999842
# 3       POSITIVE        0.999781
# 4       POSITIVE        0.999095
#
#                                       WordImportance  start_second  \
# 0  [{'SentimentWord': '', 'SentimentWordImportanc...           1.0
# 1  [{'SentimentWord': '', 'SentimentWordImportanc...           9.0
# 2  [{'SentimentWord': '', 'SentimentWordImportanc...          11.0
# 3  [{'SentimentWord': '', 'SentimentWordImportanc...          22.0
# 4  [{'SentimentWord': '', 'SentimentWordImportanc...          29.0
#
#    end_second  time_spoken  time_silence speaker_label
# 0         5.0          4.0           0.0         Agent
# 1        11.0          2.0           4.0      Employee
# 2        16.0          5.0           0.0         Agent
# 3        29.0          7.0           6.0      Employee
# 4        32.0          3.0           0.0         Agent

# %% [markdown]
# ## 7.1 Intra Calls Sentiments

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
config = AutoConfig.from_pretrained(MODEL)
model_sentiment = AutoModelForSequenceClassification.from_pretrained(MODEL)
logging.info("Sentiment Analysis Model: cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# INFO:root:Sentiment Analysis Model: cardiffnlp/twitter-roberta-base-sentiment-latest

# %%
logging.info("Started Sentiment and Shap Analysis.")
start = time.time()
dict_sentiments = []
for text in df_intra_calls_data.text:
    encoded_input = tokenizer(text, return_tensors='pt')
    output = model_sentiment(**encoded_input)
    scores = output[0][0].detach().numpy()
    scores = np.round(np.multiply(softmax(scores), 100), 2)
    # get feature Importance
    shap_score=get_shap_word_importance(sent_pipeline,explainer,text)
    # logging.info("Completed Shap Score calculations.")
    # Creating the list of Sentiment Dictionary
    merged_dict = {**dict(zip(list(config.id2label.values()), list(scores))), **shap_score}
    dict_sentiments.append(merged_dict)
    
df_intra_calls_data['SentimentLable'] = df_intra_calls_data[['positive','negative','neutral']].apply(get_sentiment_label, axis=1)
end = time.time()
df_intra_calls_data = df_intra_calls_data.join(pd.DataFrame(dict_sentiments))
logging.info("Completed Sentiment Analysis and Shap Scores in: "+str(timedelta(seconds=end-start)))
# Out:
# INFO:root:Started Sentiment and Shap Analysis.
# INFO:root:Completed Sentiment Analysis and Shap Scores in: 0:00:32.303235

# %%
# logging.info("Started adding shap sorted word list columns.")
# shap_sorted_words_list = [create_sorted_words_df(wordImp_list) for wordImp_list in df_intra_calls_data.WordImportance]
# df_intra_calls_data = df_intra_calls_data.join(pd.DataFrame(shap_sorted_words_list))
# logging.info("Completed adding shap sorted word list columns.")

# %%
df_intra_calls_data.to_csv("df_intra_calls_data.csv", index=False)
df_intra_calls_data.head()
# Out:
#   call_id  start    end speaker            text  start_second  end_second  \
# 0  279902  00:01  00:05  Ramelo             Yes           1.0         5.0
# 1  279902  00:09  00:11     Joy           Yeah.           9.0        11.0
# 2  279902  00:11  00:16  Ramelo       All right          11.0        16.0
# 3  279902  00:22  00:29     Joy             Yes          22.0        29.0
# 4  279902  00:29  00:32  Ramelo  Okay. Were you          29.0        32.0
#
#    time_spoken  time_silence speaker_label  negative  neutral  positive  \
# 0          4.0           0.0         Agent      8.97    45.49     45.53
# 1          2.0           4.0      Employee      9.89    57.98     32.13
# 2          5.0           0.0         Agent      7.15    52.12     40.73
# 3          7.0           6.0      Employee      8.97    45.49     45.53
# 4          3.0           0.0         Agent      3.45    86.24     10.31
#
#   SentimentLable  SentimentScore  \
# 0       POSITIVE        0.989574
# 1        NEUTRAL        0.989574
# 2        NEUTRAL        0.989574
# 3       POSITIVE        0.989574
# 4        NEUTRAL        0.989574
#
#                                       WordImportance
# 0  [{'SentimentWord': '', 'SentimentWordImportanc...
# 1  [{'SentimentWord': '', 'SentimentWordImportanc...
# 2  [{'SentimentWord': '', 'SentimentWordImportanc...
# 3  [{'SentimentWord': '', 'SentimentWordImportanc...
# 4  [{'SentimentWord': '', 'SentimentWordImportanc...

# %% [markdown]
# ## 7.2 Adding Silence Time and Spoken Time

# %%
def convert_to_seconds(time_str):
    try:
        # Parse time string using datetime
        time_obj = datetime.strptime(time_str, '%M:%S')
        # Convert to timedelta and extract total seconds
        total_seconds = time_obj.minute * 60 + time_obj.second
        return total_seconds
    except ValueError:
        return None  # Handle invalid time format

# Apply the function to each column using vectorized operations
df_intra_calls_data['start_second'] = df_intra_calls_data['start'].apply(convert_to_seconds)
df_intra_calls_data['end_second'] = df_intra_calls_data['end'].apply(convert_to_seconds)

# %%
df_intra_calls_data['time_spoken'] = df_intra_calls_data['end_second'] - df_intra_calls_data['start_second']
df_intra_calls_data['time_spoken'] = df_intra_calls_data['time_spoken'].where(df_intra_calls_data['time_spoken'] >= 0, 0)
df_intra_calls_data['time_spoken'] = df_intra_calls_data['time_spoken'].fillna(0)
df_intra_calls_data.head()
# Out:
#   call_id  start    end speaker            text  start_second  end_second  \
# 0  279902  00:01  00:05  Ramelo             Yes           1.0         5.0
# 1  279902  00:09  00:11     Joy           Yeah.           9.0        11.0
# 2  279902  00:11  00:16  Ramelo       All right          11.0        16.0
# 3  279902  00:22  00:29     Joy             Yes          22.0        29.0
# 4  279902  00:29  00:32  Ramelo  Okay. Were you          29.0        32.0
#
#    time_spoken  time_silence speaker_label  negative    neutral   positive  \
# 0          4.0           0.0         Agent      8.97  45.490002  45.529999
# 1          2.0           4.0      Employee      9.89  57.980000  32.130001
# 2          5.0           0.0         Agent      7.15  52.119999  40.730000
# 3          7.0           6.0      Employee      8.97  45.490002  45.529999
# 4          3.0           0.0         Agent      3.45  86.239998  10.310000
#
#   SentimentLable  SentimentScore  \
# 0       POSITIVE        0.989574
# 1       POSITIVE        0.989574
# 2       POSITIVE        0.989574
# 3       POSITIVE        0.989574
# 4       POSITIVE        0.989574
#
#                                       WordImportance
# 0  [{'SentimentWord': '', 'SentimentWordImportanc...
# 1  [{'SentimentWord': '', 'SentimentWordImportanc...
# 2  [{'SentimentWord': '', 'SentimentWordImportanc...
# 3  [{'SentimentWord': '', 'SentimentWordImportanc...
# 4  [{'SentimentWord': '', 'SentimentWordImportanc...

# %%
df_intra_calls_data['time_silence'] = df_intra_calls_data['start_second'].shift(-1) - df_intra_calls_data['end_second']
df_intra_calls_data['time_silence'] = df_intra_calls_data['time_silence'].where(df_intra_calls_data['time_silence'] >= 0, 0)
df_intra_calls_data['time_silence'] = df_intra_calls_data['time_silence'].fillna(0)
df_intra_calls_data['time_silence'] = pd.DataFrame([0] + df_intra_calls_data['time_silence'].iloc[:-1].tolist())
df_intra_calls_data.head()
# Out:
#   call_id  start    end  speaker       text  negative    neutral   positive  \
# 0  279902  00:00  00:01  Unknown     Hello.      2.23  42.529999  55.250000
# 1  279902  00:01  00:05   Ramelo        Yes      8.97  45.490002  45.529999
# 2  279902  00:09  00:11      Joy      Yeah.      9.89  57.980000  32.130001
# 3  279902  00:11  00:16   Ramelo  All right      7.15  52.119999  40.730000
# 4  279902  00:22  00:29      Joy        Yes      8.97  45.490002  45.529999
#
#   SentimentLable  SentimentScore  \
# 0       POSITIVE        0.999374
# 1       POSITIVE        0.999781
# 2       POSITIVE        0.999524
# 3       POSITIVE        0.999842
# 4       POSITIVE        0.999781
#
#                                       WordImportance  start_second  \
# 0  [{'SentimentWord': '', 'SentimentWordImportanc...           0.0
# 1  [{'SentimentWord': '', 'SentimentWordImportanc...           1.0
# 2  [{'SentimentWord': '', 'SentimentWordImportanc...           9.0
# 3  [{'SentimentWord': '', 'SentimentWordImportanc...          11.0
# 4  [{'SentimentWord': '', 'SentimentWordImportanc...          22.0
#
#    end_second  time_spoken  time_silence
# 0         1.0          1.0           0.0
# 1         5.0          4.0           0.0
# 2        11.0          2.0           4.0
# 3        16.0          5.0           0.0
# 4        29.0          7.0           6.0

# %%
df_intra_calls_data.to_csv("df_intra_calls_data.csv", index=False)

# %% [markdown]
# # 9. Persisting to BQ

# %%
# import pandas as pd
df_inter_calls_data = pd.read_csv('df_inter_calls_data.csv')
df_inter_calls_data.call_id = df_inter_calls_data.call_id.astype('str')
df_inter_calls_data.to_csv("df_inter_calls_data.csv")
# df_inter_calls_data.head()

df_intra_calls_data = pd.read_csv('df_intra_calls_data.csv')
df_intra_calls_data.call_id = df_intra_calls_data.call_id.astype('str')
df_intra_calls_data.to_csv("df_intra_calls_data.csv")
# df_intra_calls_data.head()

# %%
# # bucket_name = "tte-eid-d-gcs-mlops-users-files"
# # bucket_folder = "VoiceAI/tempFolder"
# # storage_path = f"gs://{bucket_name}/{bucket_folder}"

project_id = "eid-dw-dev-a5cf"

target_table_id = "EdwBI.Calls_Insights_Intra_Gemini-sun"
df = df_intra_calls_data

# target_table_id = "EdwBI.Calls_Insights_Inter_Gemini-sun"
# df = df_inter_calls_data

client = bigquery.Client()
job_config = bigquery.job.load.LoadJobConfig()
table_id = f"{project_id}.{target_table_id}"
job_config.write_disposition = bigquery.WriteDisposition.WRITE_TRUNCATE
job = client.load_table_from_dataframe(dataframe=df, destination=table_id, job_config=job_config, project=project_id)
job.result()
# Out:
# LoadJob<project=eid-dw-dev-a5cf, location=US, id=a25de6c7-06c9-4344-b785-09875e49bef5>

# %% [markdown]
# # Misc

# %%
df_inter_calls_data.columns
# Out:
# Index(['call_id', 'call_text', 'call_summary', 'topic', 'category',
#        'sub_category', 'overall_user_sentiments', 'overall_agent_sentiments',
#        'agent_coaching'],
#       dtype='object')
